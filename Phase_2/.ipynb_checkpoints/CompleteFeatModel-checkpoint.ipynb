# %%
# !pip install tensorflow-gpu
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Conv3D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K
import tensorflow as tf
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta
from pandas import DataFrame as df
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
    
def CompleteModel(months, lats,lons , featureNum, spatialKernelShape = (4,4),
            S1 = 2, norm_rate = 0.25,):
    temporalKernelShape = (1,1)
    input1   = Input(shape = (lats,lons, months * featureNum))
    
    ##################################################################
    block1 = BatchNormalization()(input1)
    block1 = AveragePooling2D((4, 4), padding='valid',strides = (4,4))(block1)
    # Spatial Informaiton Extraction
    block1 = DepthwiseConv2D(depth_multiplier = 1,kernel_size = spatialKernelShape, padding = 'same',strides = (1,1))(block1)
    block1 = AveragePooling2D((4, 4),padding='same',strides = (4,4))(block1)
    block1 = BatchNormalization()(block1)
    # Temporal Information Extraction
    block1 = Conv2D(filters = featureNum*2,groups = 2,kernel_size = temporalKernelShape, padding = 'same',strides = (1,1))(block1)
    block1 = Activation('leaky_relu')(block1)
    block1 = AveragePooling2D((4, 4),padding='same',strides = (1,1))(block1)
        
    block2 = SeparableConv2D(S1, (2,2),
                                   use_bias = False, padding = 'same')(block1)
    block2       = Activation('leaky_relu')(block2)
    flatten = Flatten()(block2)
    
    dense1 = Dense(10,activation = 'leaky_relu')(flatten)
    dense2 = Dense(1, activation = 'linear',use_bias = True)(dense1)
    
    return Model(inputs=input1, outputs=dense2)

def AlternateModel(months, lats,lons , featureNum, spatialKernelShape = (4,4),
            S1 = 2, norm_rate = 0.25,):
    temporalKernelShape = (1,1)
    input1   = Input(shape = (lats,lons, months * featureNum))
    
    ##################################################################
    block1 = BatchNormalization()(input1)
    block1 = AveragePooling2D((4, 4), padding='valid',strides = (4,4))(input1)
    # Spatial Informaiton Extraction
    block1 = DepthwiseConv2D(depth_multiplier = 1,kernel_size = spatialKernelShape, padding = 'same',strides = (1,1))(block1)
    block1 = AveragePooling2D((4, 4),padding='same',strides = (4,4))(block1)
    # block1 = BatchNormalization()(block1)
    # Temporal Information Extraction
    block1 = Conv2D(filters = 1,groups = 1,kernel_size = temporalKernelShape, padding = 'same',strides = (1,1))(block1)
    block1 = Activation('leaky_relu')(block1)
    block1 = AveragePooling2D((4, 4),padding='same',strides = (1,1))(block1)
        
    block2 = SeparableConv2D(S1, (2,2),
                                   use_bias = True, padding = 'same')(block1)
    block2       = Activation('leaky_relu')(block2)
    flatten = Flatten()(block2)
    
    dense1 = Dense(10,activation = 'leaky_relu')(flatten)
    dense2 = Dense(1, activation = 'linear',use_bias = True)(dense1)
    
    return Model(inputs=input1, outputs=dense2)
# Out:
# WARNING: Ignoring invalid distribution -eras (/Users/jackzhang/opt/anaconda3/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -eras (/Users/jackzhang/opt/anaconda3/lib/python3.8/site-packages)
# ERROR: Could not find a version that satisfies the requirement tensorflow-gpu (from versions: none)
# ERROR: No matching distribution found for tensorflow-gpu
# WARNING: Ignoring invalid distribution -eras (/Users/jackzhang/opt/anaconda3/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -eras (/Users/jackzhang/opt/anaconda3/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -eras (/Users/jackzhang/opt/anaconda3/lib/python3.8/site-packages)
#
# [notice] A new release of pip available: 22.2.1 -> 22.3
# [notice] To update, run: pip install --upgrade pip

# %%
# Read Data
feat = pd.read_csv("../Data/MERRA2/Features.csv").drop(['Unnamed: 0'],axis = 1)
TCcount = pd.read_csv("../Data/TC Count/IBTrACS/IBTrACS(1980-P, 100W-20W&10N-40N).csv")
feat['time'] = pd.to_datetime(feat['time'])
feat = feat.loc[(feat['time'].dt.month <= 5) & (feat['time'].dt.year > 1980) & (feat['time'].dt.year < 2022)]
TCcount = TCcount.loc[(TCcount['SEASON'] > 1980) & (TCcount['SEASON'] < 2022)]

# %%
feat
# Out:
#               time    lon   lat  OMEGA500         SLP       U500  \
# 86559   1981-01-01 -100.0  10.0  0.021865  101288.120   0.068800
# 86560   1981-01-01 -100.0  10.5  0.021120  101302.380   0.289666
# 86561   1981-01-01 -100.0  11.0  0.020317  101314.880   0.573919
# 86562   1981-01-01 -100.0  11.5  0.019704  101325.800   0.992850
# 86563   1981-01-01 -100.0  12.0  0.019548  101336.220   1.548453
# ...            ...    ...   ...       ...         ...        ...
# 3903019 2021-05-01  -20.0  38.0  0.047377  102329.010  11.301683
# 3903020 2021-05-01  -20.0  38.5  0.043600  102311.770  11.961118
# 3903021 2021-05-01  -20.0  39.0  0.039673  102289.930  12.615298
# 3903022 2021-05-01  -20.0  39.5  0.035402  102264.110  13.247641
# 3903023 2021-05-01  -20.0  40.0  0.032196  102235.266  13.890990
#
#               SSSMASS  month  year
# 86559    5.465323e-08      1  1981
# 86560    5.707235e-08      1  1981
# 86561    5.961355e-08      1  1981
# 86562    6.157003e-08      1  1981
# 86563    6.336287e-08      1  1981
# ...               ...    ...   ...
# 3903019  1.996896e-08      5  2021
# 3903020  2.106846e-08      5  2021
# 3903021  2.258790e-08      5  2021
# 3903022  2.417287e-08      5  2021
# 3903023  2.602483e-08      5  2021
#
# [1613145 rows x 9 columns]

# %%
# reshaped inputs to years * number of features times number of months * longitudes * latitudes
# in every year (3D dataset), features (2D layer) across months are stacked together. 
# i.e., first 5 layers are the OMEGA500 from Jan to May in that year, 6-10 are SLP, 11-15 are U500, etc.
coordinations = len(np.unique(feat['lon'])) * len(np.unique(feat['lat']))
years = np.unique(feat['year'])
months = np.unique(feat['month'])
lons = np.unique(feat['lon'])
lats = np.unique(feat['lat'])
featuresNum = 4
features = ['OMEGA500','SLP','U500','SSSMASS']
x = np.zeros((len(years),featuresNum * len(months),len(lons),len(lats)))
for yearIndex in range(len(years)):
    tempDF = feat.loc[feat['year'] == years[yearIndex]]
    for featIndex in range(featuresNum):
        x[yearIndex,featIndex * len(months) : (featIndex + 1)*len(months)] = tempDF[features[featIndex]].to_numpy().reshape(len(months),len(lons),len(lats))

# %%
# sanity check
x[3,5,3,4] == feat.loc[(feat['year'] == years[3]) & (feat['month'] == months[0]) 
                       & (feat['lon'] == lons[3]) 
                       & (feat['lat'] == lats[4])]['SLP']
# Out:
# 370030    True
# Name: SLP, dtype: bool

# %%
plt.figure(figsize=(30,10))
plt.imshow(x[0,5,:,:], cmap='cool')
plt.colorbar()
plt.show()

# %%
x = x.transpose(0,3,2,1)

# %%
model = AlternateModel(len(months),len(lats),len(lons),featuresNum)

# %%
model.summary()
# Out:
# Model: "model_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_35 (InputLayer)       [(None, 61, 129, 20)]     0
#
#  average_pooling2d_45 (Avera  (None, 15, 32, 20)       0
#  gePooling2D)
#
#  depthwise_conv2d_22 (Depthw  (None, 15, 32, 20)       340
#  iseConv2D)
#
#  average_pooling2d_46 (Avera  (None, 4, 8, 20)         0
#  gePooling2D)
#
#  conv2d_32 (Conv2D)          (None, 4, 8, 1)           21
#
#  activation_37 (Activation)  (None, 4, 8, 1)           0
#
#  average_pooling2d_47 (Avera  (None, 4, 8, 1)          0
#  gePooling2D)
#
#  separable_conv2d_22 (Separa  (None, 4, 8, 2)          8
#  bleConv2D)
#
#  activation_38 (Activation)  (None, 4, 8, 2)           0
#
#  flatten_22 (Flatten)        (None, 64)                0
#
#  dense_38 (Dense)            (None, 10)                650
#
#  dense_39 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 1,030
# Trainable params: 1,030
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(lr=0.05)
model.compile(optimizer=optimizer,loss='mse',metrics=[tf.keras.metrics.MeanSquaredError()])
X_train, X_test, y_train, y_test = train_test_split(x, TCcount['COUNT'], test_size=0.10, random_state=42)
es = EarlyStopping(monitor='mean_squared_error', verbose=1, patience = 2,min_delta = 0.001)
hist = model.fit(X_train, y_train,batch_size=8,epochs = 25, verbose=1,validation_data= (X_test,y_test),callbacks = [es])
plt.plot(model.predict(X_train))
plt.plot(np.arange(1,37,1),y_train)
# Out:
# Epoch 1/25
# /Users/jackzhang/opt/anaconda3/lib/python3.8/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 5/5 [==============================] - 1s 36ms/step - loss: 266834.0000 - mean_squared_error: 266834.0000 - val_loss: 35340.9180 - val_mean_squared_error: 35340.9180
# Epoch 2/25
# 5/5 [==============================] - 0s 11ms/step - loss: 39336.0156 - mean_squared_error: 39336.0156 - val_loss: 33229.1328 - val_mean_squared_error: 33229.1328
# Epoch 3/25
# 5/5 [==============================] - 0s 10ms/step - loss: 24121.9395 - mean_squared_error: 24121.9395 - val_loss: 4095.0093 - val_mean_squared_error: 4095.0093
# Epoch 4/25
# 5/5 [==============================] - 0s 10ms/step - loss: 6543.0645 - mean_squared_error: 6543.0645 - val_loss: 63.6922 - val_mean_squared_error: 63.6922
# Epoch 5/25
# 5/5 [==============================] - 0s 10ms/step - loss: 733.5865 - mean_squared_error: 733.5865 - val_loss: 1776.3695 - val_mean_squared_error: 1776.3695
# Epoch 6/25
# 5/5 [==============================] - 0s 11ms/step - loss: 1436.2480 - mean_squared_error: 1436.2480 - val_loss: 522.0305 - val_mean_squared_error: 522.0305
# Epoch 7/25
# 5/5 [==============================] - 0s 10ms/step - loss: 257.3976 - mean_squared_error: 257.3976 - val_loss: 55.8867 - val_mean_squared_error: 55.8867
# Epoch 8/25
# 5/5 [==============================] - 0s 10ms/step - loss: 35.6218 - mean_squared_error: 35.6218 - val_loss: 57.3873 - val_mean_squared_error: 57.3873
# Epoch 9/25
# 5/5 [==============================] - 0s 10ms/step - loss: 25.8373 - mean_squared_error: 25.8373 - val_loss: 58.5460 - val_mean_squared_error: 58.5460
# Epoch 10/25
# 5/5 [==============================] - 0s 11ms/step - loss: 24.6993 - mean_squared_error: 24.6993 - val_loss: 55.8222 - val_mean_squared_error: 55.8222
# Epoch 11/25
# 5/5 [==============================] - 0s 11ms/step - loss: 24.5488 - mean_squared_error: 24.5488 - val_loss: 56.1551 - val_mean_squared_error: 56.1551
# Epoch 12/25
# 5/5 [==============================] - 0s 11ms/step - loss: 26.5447 - mean_squared_error: 26.5447 - val_loss: 58.0882 - val_mean_squared_error: 58.0882
# Epoch 13/25
# 5/5 [==============================] - 0s 10ms/step - loss: 24.7514 - mean_squared_error: 24.7514 - val_loss: 56.2888 - val_mean_squared_error: 56.2888
# Epoch 13: early stopping

# %%
feat
# Out:
#               time    lon   lat  OMEGA500         SLP       U500  \
# 86559   1981-01-01 -100.0  10.0  0.021865  101288.120   0.068800
# 86560   1981-01-01 -100.0  10.5  0.021120  101302.380   0.289666
# 86561   1981-01-01 -100.0  11.0  0.020317  101314.880   0.573919
# 86562   1981-01-01 -100.0  11.5  0.019704  101325.800   0.992850
# 86563   1981-01-01 -100.0  12.0  0.019548  101336.220   1.548453
# ...            ...    ...   ...       ...         ...        ...
# 3903019 2021-05-01  -20.0  38.0  0.047377  102329.010  11.301683
# 3903020 2021-05-01  -20.0  38.5  0.043600  102311.770  11.961118
# 3903021 2021-05-01  -20.0  39.0  0.039673  102289.930  12.615298
# 3903022 2021-05-01  -20.0  39.5  0.035402  102264.110  13.247641
# 3903023 2021-05-01  -20.0  40.0  0.032196  102235.266  13.890990
#
#               SSSMASS  month  year
# 86559    5.465323e-08      1  1981
# 86560    5.707235e-08      1  1981
# 86561    5.961355e-08      1  1981
# 86562    6.157003e-08      1  1981
# 86563    6.336287e-08      1  1981
# ...               ...    ...   ...
# 3903019  1.996896e-08      5  2021
# 3903020  2.106846e-08      5  2021
# 3903021  2.258790e-08      5  2021
# 3903022  2.417287e-08      5  2021
# 3903023  2.602483e-08      5  2021
#
# [1613145 rows x 9 columns]

# %%
y_train.shape
# Out:
# (36,)
