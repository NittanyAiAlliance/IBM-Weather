# %%
import pandas as pd
from google.colab import files
import io
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Cleaning and Pre-Processing

# %%
df_AMM_JJASOM_mean = pd.read_table('./Data/AMM_JJASOM_mean_1950-2020.dat', sep="\s+", header=None)
df_AMM_JJASOM_mean = df_AMM_JJASOM_mean.rename(columns={0: "Year", 1:"AMM_JJASOM_mean"}).copy()
df_AMM_JJASOM_mean
# Out:
#     Year  AMM_JJASOM_mean
# 0   1950         1.016667
# 1   1951         0.916667
# 2   1952         2.373333
# 3   1953         1.163333
# 4   1954        -0.635000
# ..   ...              ...
# 66  2016         1.530000
# 67  2017         2.618333
# 68  2018        -2.171667
# 69  2019         0.566667
# 70  2020         1.467830
#
# [71 rows x 2 columns]

# %%
df_ERSSTv5_ASO_MDRRelative = pd.read_table('./Data/ERSSTv5_ASO_MDRRelative_SST_1870-2020.dat', sep="\s+", header=None)
df_ERSSTv5_ASO_MDRRelative
# Out:
#             0
# 0    0.239469
# 1   -0.396031
# 2   -0.743195
# 3   -0.021984
# 4    0.161659
# ..        ...
# 146  0.082054
# 147  0.221386
# 148 -0.232869
# 149 -0.098519
# 150  0.183437
#
# [151 rows x 1 columns]

# %%
df_ERSSTv5_ASO_MDR = pd.read_table('./Data/ERSSTv5_ASO_MDR_SST_1870-2020.dat', sep="\s+", header=None)
df_ERSSTv5_ASO_MDR
# Out:
#             0
# 0    27.65656
# 1    27.01905
# 2    26.62783
# 3    27.38899
# 4    27.44587
# ..        ...
# 146  28.36498
# 147  28.43985
# 148  27.93210
# 149  28.12645
# 150  28.35310
#
# [151 rows x 1 columns]

# %%
df_ERSSTv5_ASO_MDR_anomalies = pd.read_table('./Data/ERSSTv5_ASO_MDR_SST_anomalies_1870-2020.dat', sep="\s+", header=None)
df_ERSSTv5_ASO_MDR_anomalies
# Out:
#             0
# 0   -0.233739
# 1   -0.871248
# 2   -1.262471
# 3   -0.501313
# 4   -0.444434
# ..        ...
# 146  0.474681
# 147  0.549548
# 148  0.041802
# 149  0.236148
# 150  0.462798
#
# [151 rows x 1 columns]

# %%
df_ERSSTv5_ASO_MDR_tropics = pd.read_table('./Data/ERSSTv5_ASO_tropics_SST_1870-2020.dat', sep="\s+", header=None)
df_ERSSTv5_ASO_MDR_tropics
# Out:
#             0
# 0    25.89209
# 1    25.89008
# 2    25.84602
# 3    25.88597
# 4    25.75921
# ..        ...
# 146  26.75793
# 147  26.69346
# 148  26.63997
# 149  26.69997
# 150  26.64466
#
# [151 rows x 1 columns]

# %%
df_ERSSTv5_ASO_MDR_tropics_anomalies = pd.read_table('./Data/ERSSTv5_ASO_tropics_SST_anomalies_1870-2020.dat', sep="\s+", header=None)
df_ERSSTv5_ASO_MDR_tropics_anomalies
# Out:
#             0
# 0   -0.473208
# 1   -0.475217
# 2   -0.519276
# 3   -0.479329
# 4   -0.606093
# ..        ...
# 146  0.392627
# 147  0.328162
# 148  0.274671
# 149  0.334666
# 150  0.279361
#
# [151 rows x 1 columns]

# %%
df_HURDAT_TCCounts = pd.read_table('./Data/HURDAT_TCCounts_1870-2020.dat', sep="\s+", header=None)
df_HURDAT_TCCounts
# Out:
#         0   1
# 0    1870  11
# 1    1871   8
# 2    1872   5
# 3    1873   5
# 4    1874   7
# ..    ...  ..
# 146  2016  15
# 147  2017  17
# 148  2018  15
# 149  2019  18
# 150  2020  30
#
# [151 rows x 2 columns]

# %%
df_NAO_DJFM_mean = pd.read_table('./Data/NAO_DJFM_mean_1870-2020.dat', sep="\s+", header=None)
df_NAO_DJFM_mean
# Out:
#         0        1
# 0    1870  0.00275
# 1    1871  0.05475
# 2    1872  0.24850
# 3    1873  1.77750
# 4    1874 -0.53575
# ..    ...      ...
# 146  2016  1.17500
# 147  2017  0.39925
# 148  2018  1.46525
# 149  2019  2.22850
# 150  2020 -0.13500
#
# [151 rows x 2 columns]

# %%
df_NAO_MJ_mean = pd.read_table('./Data/NAO_MJ_mean_1870-2020.dat', sep="\s+", header=None)
df_NAO_MJ_mean
# Out:
#         0       1
# 0    1870  1.0530
# 1    1871 -1.9325
# 2    1872 -0.1640
# 3    1873 -0.0725
# 4    1874 -1.3055
# ..    ...     ...
# 146  2016 -1.0485
# 147  2017 -0.0835
# 148  2018  0.3060
# 149  2019 -0.3895
# 150  2020 -0.8060
#
# [151 rows x 2 columns]

# %%
df_Nino12_DJF = pd.read_table('./Data/Nino12_DJF_1870-2020.dat', sep="\s+", header=None)
df_Nino12_DJF
# Out:
#         0         1
# 0    1870 -0.850000
# 1    1871 -1.156667
# 2    1872 -1.003333
# 3    1873 -1.156667
# 4    1874 -0.676667
# ..    ...       ...
# 146  2016  0.423333
# 147  2017 -1.073333
# 148  2018  0.706667
# 149  2019 -0.113333
# 150  2020 -0.633000
#
# [151 rows x 2 columns]

# %%
df_Nino34_DJF = pd.read_table('./Data/Nino34_DJF_1870-2020.dat', sep="\s+", header=None)
df_Nino34_DJF
# Out:
#         0         1
# 0    1870 -0.540000
# 1    1871 -0.640000
# 2    1872 -0.890000
# 3    1873 -0.896667
# 4    1874 -0.740000
# ..    ...       ...
# 146  2016 -0.286667
# 147  2017 -0.813333
# 148  2018  0.700000
# 149  2019  0.543333
# 150  2020 -0.987000
#
# [151 rows x 2 columns]

# %%
df_Nino3_DJF = pd.read_table('./Data/Nino3_DJF_1870-2020.dat', sep="\s+", header=None)
df_Nino3_DJF
# Out:
#         0         1
# 0    1870 -0.573333
# 1    1871 -0.710000
# 2    1872 -1.046667
# 3    1873 -1.276667
# 4    1874 -0.793333
# ..    ...       ...
# 146  2016 -0.056667
# 147  2017 -1.010000
# 148  2018  0.720000
# 149  2019  0.273333
# 150  2020 -0.650000
#
# [151 rows x 2 columns]

# %%
df_SahelPrecipIndex_JJAS_mean = pd.read_table('./Data/SahelPrecipIndex_JJAS_mean_1901-2017.dat', sep="\s+", header=None)
df_SahelPrecipIndex_JJAS_mean = df_SahelPrecipIndex_JJAS_mean.rename(columns={0: "Year", 1:"SahelPrecipIndex_JJAS_mean"}).copy()

# %%
df_SahelPrecipIndex_JJAS_mean
# Out:
#      Year  SahelPrecipIndex_JJAS_mean
# 0    1901                      3.7100
# 1    1902                      0.1200
# 2    1903                      2.0825
# 3    1904                      0.9850
# 4    1905                      2.5625
# ..    ...                         ...
# 112  2013                      0.6425
# 113  2014                      0.5050
# 114  2015                      3.0375
# 115  2016                      2.5250
# 116  2017                      1.2625
#
# [117 rows x 2 columns]

# %%
df_VK08_TCCount = pd.read_table('./Data/VK08_TCCounts_1878-2020.dat', sep="\s+", header=None)
df_VK08_TCCount = df_VK08_TCCount.rename(columns={0: "Year", 1:"VK08_TCCount"}).copy()
df_VK08_TCCount
# Out:
#      Year  VK08_TCCount
# 0    1878        15.370
# 1    1879        11.308
# 2    1880        14.084
# 3    1881        10.234
# 4    1882         9.183
# ..    ...           ...
# 138  2016        15.000
# 139  2017        17.000
# 140  2018        15.000
# 141  2019        18.000
# 142  2020        30.000
#
# [143 rows x 2 columns]

# %%
df_hurricanefinal = pd.DataFrame()

# %%
df_hurricanefinal['Year'] = df_HURDAT_TCCounts[0]
df_hurricanefinal['HURRICANE_COUNT'] = df_HURDAT_TCCounts[1]

df_hurricanefinal['ERSSTv5_ASO_MDRRelative'] = df_ERSSTv5_ASO_MDRRelative[0]
df_hurricanefinal['ERSSTv5_ASO_MDR'] = df_ERSSTv5_ASO_MDR[0] 
df_hurricanefinal['ERSSTv5_ASO_MDR_anomalies'] = df_ERSSTv5_ASO_MDR_anomalies[0] 
df_hurricanefinal['ERSSTv5_ASO_MDR_tropics'] = df_ERSSTv5_ASO_MDR_tropics[0] 
df_hurricanefinal['ERSSTv5_ASO_MDR_tropics_anomalies'] = df_ERSSTv5_ASO_MDR_tropics_anomalies[0] 
df_hurricanefinal['ERSSTv5_ASO_MDR'] = df_ERSSTv5_ASO_MDR[0] 

df_hurricanefinal['NAO_DJFM_mean'] = df_NAO_DJFM_mean[1]
df_hurricanefinal['NAO_MJ_mean'] = df_NAO_MJ_mean[1] 

df_hurricanefinal['Nino12_DJF'] = df_Nino12_DJF[1]
df_hurricanefinal['Nino34_DJF'] = df_Nino34_DJF[1] 
df_hurricanefinal['Nino3_DJF'] = df_Nino3_DJF[1]

# %%
df_hurricanefinal = pd.merge(df_hurricanefinal, df_AMM_JJASOM_mean,how = "left", on=['Year'])
df_hurricanefinal = pd.merge(df_hurricanefinal, df_VK08_TCCount,how = "left", on=['Year'])
df_hurricanefinal = pd.merge(df_hurricanefinal, df_SahelPrecipIndex_JJAS_mean,how = "left", on=['Year'])

# %%
df_hurricanefinal
# Out:
#      Year  HURRICANE_COUNT  ...  VK08_TCCount  SahelPrecipIndex_JJAS_mean
# 0    1870               11  ...           NaN                         NaN
# 1    1871                8  ...           NaN                         NaN
# 2    1872                5  ...           NaN                         NaN
# 3    1873                5  ...           NaN                         NaN
# 4    1874                7  ...           NaN                         NaN
# ..    ...              ...  ...           ...                         ...
# 146  2016               15  ...          15.0                      2.5250
# 147  2017               17  ...          17.0                      1.2625
# 148  2018               15  ...          15.0                         NaN
# 149  2019               18  ...          18.0                         NaN
# 150  2020               30  ...          30.0                         NaN
#
# [151 rows x 15 columns]

# %%
df_hurricanefinalVK08Counts = df_hurricanefinal.dropna(subset=['VK08_TCCount'])

# %% [markdown]
# #XG BOOST

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split 
from sklearn.metrics import mean_squared_error as MSE 
import matplotlib.pyplot as plt
# !pip install eli5
from eli5 import show_weights
from eli5 import explain_prediction
from IPython.display import display
import eli5
# Out:
# Requirement already satisfied: eli5 in /usr/local/lib/python3.7/dist-packages (0.11.0)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from eli5) (1.19.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from eli5) (2.11.3)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (from eli5) (0.10.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from eli5) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.7/dist-packages (from eli5) (1.0.2)
# Requirement already satisfied: attrs>16.0.0 in /usr/local/lib/python3.7/dist-packages (from eli5) (21.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from eli5) (1.15.0)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from eli5) (0.8.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20->eli5) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20->eli5) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->eli5) (2.0.1)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
test2005 = df_hurricanefinalVK08Counts.loc[df_hurricanefinalVK08Counts.Year == 2005].drop(columns=['HURRICANE_COUNT',"VK08_TCCount", 'Year'],axis=1)
test2020 = df_hurricanefinalVK08Counts.loc[df_hurricanefinalVK08Counts.Year == 2020].drop(columns=['HURRICANE_COUNT',"VK08_TCCount", 'Year'],axis=1)
test1999 = df_hurricanefinalVK08Counts.loc[df_hurricanefinalVK08Counts.Year == 1999].drop(columns=['HURRICANE_COUNT',"VK08_TCCount", 'Year'],axis=1)

# %%
df_hurricanefinal1 = df_hurricanefinalVK08Counts.loc[df_hurricanefinal.Year != 2005]
df_hurricanefinal1 = df_hurricanefinal1.loc[df_hurricanefinal.Year != 2020]

X = df_hurricanefinal1.drop(columns=['HURRICANE_COUNT',"VK08_TCCount", 'Year'],axis=1)
y = df_hurricanefinal1['VK08_TCCount']
# Splitting 
train_X, test_X, train_y, test_y = train_test_split(X, y, 
                      test_size = 0.3) 
  
# Instantiation 
xgb_r = xgb.XGBRegressor(objective ='reg:linear', 
                  n_estimators = 10) 
  
# Fitting the model 
xgb_r.fit(train_X, train_y) 
  
# Predict the model 
pred = xgb_r.predict(test_X) 
  
# RMSE Computation 
rmse = mean_absolute_error(test_y,pred)

print("MAE : % f" %(rmse))
# Out:
# [18:13:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# MAE :  4.423395

# %%
dtrain = xgb.DMatrix(train_X, label=train_y)
dtest = xgb.DMatrix(test_X, label=test_y)

# %%
params = {
    # Parameters that we are going to tune.
    'max_depth':6,
    'min_child_weight': 1,
    'eta':.2,
    'subsample': 1,
    'colsample_bytree': 1,
    # Other parameters
    'objective':'reg:linear',
}

# %%
params['eval_metric'] = "mae"

# %%
num_boost_round = 999

# %%
xgmodel = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)
# Out:
# [18:13:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test-mae:8.50114
# Will train until Test-mae hasn't improved in 10 rounds.
# [1]	Test-mae:7.0142
# [2]	Test-mae:5.97336
# [3]	Test-mae:5.14276
# [4]	Test-mae:4.54585
# [5]	Test-mae:4.05028
# [6]	Test-mae:3.71566
# [7]	Test-mae:3.50055
# [8]	Test-mae:3.33239
# [9]	Test-mae:3.21087
# [10]	Test-mae:3.13802
# [11]	Test-mae:3.08507
# [12]	Test-mae:3.03451
# [13]	Test-mae:2.98194
# [14]	Test-mae:2.95104
# [15]	Test-mae:2.92693
# [16]	Test-mae:2.91089
# [17]	Test-mae:2.90338
# [18]	Test-mae:2.88903
# [19]	Test-mae:2.87575
# [20]	Test-mae:2.87572
# [21]	Test-mae:2.87671
# [22]	Test-mae:2.87729
# [23]	Test-mae:2.87288
# [24]	Test-mae:2.86751
# [25]	Test-mae:2.86537
# [26]	Test-mae:2.86346
# [27]	Test-mae:2.86258
# [28]	Test-mae:2.87003
# [29]	Test-mae:2.86863
# [30]	Test-mae:2.86979
# [31]	Test-mae:2.87004
# [32]	Test-mae:2.87033
# [33]	Test-mae:2.87051
# [34]	Test-mae:2.86923
# [35]	Test-mae:2.86779
# [36]	Test-mae:2.86782
# [37]	Test-mae:2.86875
# Stopping. Best iteration:
# [27]	Test-mae:2.86258

# %%
show_weights(xgmodel)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3152
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ERSSTv5_ASO_MDR
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.62%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2166
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Nino34_DJF
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.27%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1295
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AMM_JJASOM_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.28%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0664
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 SahelPrecipIndex_JJAS_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.32%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0658
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ERSSTv5_ASO_MDR_tropics
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0515
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ERSSTv5_ASO_MDRRelative
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0454
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Nino3_DJF
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0434
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Nino12_DJF
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.41%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0385
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NAO_MJ_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.35%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0278
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NAO_DJFM_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ERSSTv5_ASO_MDR_tropics_anomalies
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ERSSTv5_ASO_MDR_anomalies
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
xgb.plot_importance(xgmodel, max_num_features=25)
plt.rcParams['figure.figsize'] = [5, 5]
plt.show()

# %%
plt.rcParams['figure.figsize'] = [25, 12.5]

# %%
xgb.plot_tree(xgmodel)

# %%
explain_prediction(xgmodel, test2005.iloc[0])
# Out:
# Explanation(estimator='<xgboost.core.Booster object at 0x7fc4244a54d0>', description='\nFeatures with largest coefficients.\n\nFeature weights are calculated by following decision paths in trees\nof an ensemble. Each leaf has an output score, and expected scores can also be\nassigned to parent nodes. Contribution of one feature on the decision path\nis how much expected score changes from parent to child. Weights of all \nfeatures sum to the output score of the estimator.\n\nCaveats:\n1. Feature weights just show if the feature contributed positively or\n   negatively to the final score, and does not show how increasing or\n   decreasing the feature value will change the prediction.\n2. In some cases, feature weight can be close to zero for an important feature.\n   For example, in a single tree that computes XOR function, the feature at the\n   top of the tree will have zero weight because expected scores for both\n   branches are equal, so decision at the top feature does not change the\n   expected score. For an ensemble predicting XOR functions it might not be\n   a problem, but it is not reliable if most trees happen to choose the same\n   feature at the top.\n', error=None, method='decision paths', is_regression=True, targets=[TargetExplanation(target='y', feature_weights=FeatureWeights(pos=[FeatureWeight(feature='<BIAS>', weight=9.94768836351079, std=None, value=1.0), FeatureWeight(feature='ERSSTv5_ASO_MDR', weight=3.72819149144914, std=None, value=28.43595), FeatureWeight(feature='Nino34_DJF', weight=1.2351397532993114, std=None, value=-0.813333333), FeatureWeight(feature='ERSSTv5_ASO_MDR_tropics', weight=0.6561026626042727, std=None, value=26.4549), FeatureWeight(feature='NAO_DJFM_mean', weight=0.6102311954884445, std=None, value=-0.81775), FeatureWeight(feature='AMM_JJASOM_mean', weight=0.6064815638750003, std=None, value=4.048333333), FeatureWeight(feature='Nino12_DJF', weight=0.5344499561538463, std=None, value=-0.5166666670000001), FeatureWeight(feature='NAO_MJ_mean', weight=0.3429847448883888, std=None, value=-0.5675), FeatureWeight(feature='ERSSTv5_ASO_MDRRelative', weight=0.17682377216004055, std=None, value=0.45604290000000003)], neg=[FeatureWeight(feature='SahelPrecipIndex_JJAS_mean', weight=-0.12472174224423077, std=None, value=0.4725), FeatureWeight(feature='Nino3_DJF', weight=-0.08937681492500005, std=None, value=-0.856666667)], pos_remaining=0, neg_remaining=0), proba=None, score=17.623994946259998, weighted_spans=None, heatmap=None)], feature_importances=None, decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
explain_prediction(xgmodel, test2020.iloc[0])
# Out:
# Explanation(estimator='<xgboost.core.Booster object at 0x7fc4244a54d0>', description='\nFeatures with largest coefficients.\n\nFeature weights are calculated by following decision paths in trees\nof an ensemble. Each leaf has an output score, and expected scores can also be\nassigned to parent nodes. Contribution of one feature on the decision path\nis how much expected score changes from parent to child. Weights of all \nfeatures sum to the output score of the estimator.\n\nCaveats:\n1. Feature weights just show if the feature contributed positively or\n   negatively to the final score, and does not show how increasing or\n   decreasing the feature value will change the prediction.\n2. In some cases, feature weight can be close to zero for an important feature.\n   For example, in a single tree that computes XOR function, the feature at the\n   top of the tree will have zero weight because expected scores for both\n   branches are equal, so decision at the top feature does not change the\n   expected score. For an ensemble predicting XOR functions it might not be\n   a problem, but it is not reliable if most trees happen to choose the same\n   feature at the top.\n', error=None, method='decision paths', is_regression=True, targets=[TargetExplanation(target='y', feature_weights=FeatureWeights(pos=[FeatureWeight(feature='ERSSTv5_ASO_MDR', weight=13.448692204671746, std=None, value=28.3531), FeatureWeight(feature='<BIAS>', weight=9.94768836351079, std=None, value=1.0), FeatureWeight(feature='Nino34_DJF', weight=1.2351397532993114, std=None, value=-0.987), FeatureWeight(feature='ERSSTv5_ASO_MDR_tropics', weight=0.6561026626042727, std=None, value=26.64466), FeatureWeight(feature='NAO_MJ_mean', weight=0.6059834172115387, std=None, value=-0.8059999999999999), FeatureWeight(feature='AMM_JJASOM_mean', weight=0.5406530915000003, std=None, value=1.46783), FeatureWeight(feature='Nino12_DJF', weight=0.5344499561538463, std=None, value=-0.633), FeatureWeight(feature='Nino3_DJF', weight=0.3575072597000001, std=None, value=-0.65), FeatureWeight(feature='ERSSTv5_ASO_MDRRelative', weight=0.17003332866184362, std=None, value=0.183437)], neg=[FeatureWeight(feature='SahelPrecipIndex_JJAS_mean', weight=-0.08793278116730768, std=None, value=0.0), FeatureWeight(feature='NAO_DJFM_mean', weight=-0.037501252846031785, std=None, value=-0.135)], pos_remaining=0, neg_remaining=0), proba=None, score=27.370816003300003, weighted_spans=None, heatmap=None)], feature_importances=None, decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
explain_prediction(xgmodel, test1999.iloc[0])
# Out:
# Explanation(estimator='<xgboost.core.Booster object at 0x7fc4244a54d0>', description='\nFeatures with largest coefficients.\n\nFeature weights are calculated by following decision paths in trees\nof an ensemble. Each leaf has an output score, and expected scores can also be\nassigned to parent nodes. Contribution of one feature on the decision path\nis how much expected score changes from parent to child. Weights of all \nfeatures sum to the output score of the estimator.\n\nCaveats:\n1. Feature weights just show if the feature contributed positively or\n   negatively to the final score, and does not show how increasing or\n   decreasing the feature value will change the prediction.\n2. In some cases, feature weight can be close to zero for an important feature.\n   For example, in a single tree that computes XOR function, the feature at the\n   top of the tree will have zero weight because expected scores for both\n   branches are equal, so decision at the top feature does not change the\n   expected score. For an ensemble predicting XOR functions it might not be\n   a problem, but it is not reliable if most trees happen to choose the same\n   feature at the top.\n', error=None, method='decision paths', is_regression=True, targets=[TargetExplanation(target='y', feature_weights=FeatureWeights(pos=[FeatureWeight(feature='<BIAS>', weight=9.94768836351079, std=None, value=1.0), FeatureWeight(feature='Nino34_DJF', weight=1.7007367958518294, std=None, value=-1.62), FeatureWeight(feature='AMM_JJASOM_mean', weight=0.8415801263993967, std=None, value=0.975), FeatureWeight(feature='ERSSTv5_ASO_MDR', weight=0.2527895850492205, std=None, value=27.93422), FeatureWeight(feature='ERSSTv5_ASO_MDRRelative', weight=0.016880930749171047, std=None, value=0.2835747)], neg=[FeatureWeight(feature='NAO_MJ_mean', weight=-2.0066329187653342, std=None, value=1.2065), FeatureWeight(feature='NAO_DJFM_mean', weight=-0.44056308530019456, std=None, value=1.84575), FeatureWeight(feature='ERSSTv5_ASO_MDR_tropics', weight=-0.34400989460930503, std=None, value=26.12564), FeatureWeight(feature='Nino3_DJF', weight=-0.10755488100956881, std=None, value=-1.44), FeatureWeight(feature='SahelPrecipIndex_JJAS_mean', weight=-0.06247998617561715, std=None, value=2.64), FeatureWeight(feature='Nino12_DJF', weight=-0.029790288013383657, std=None, value=-0.806666667)], pos_remaining=0, neg_remaining=0), proba=None, score=9.768644747687, weighted_spans=None, heatmap=None)], feature_importances=None, decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %% [markdown]
# # Tensorflow

# %%
df_hurricanefinal = df_hurricanefinal.fillna(0).copy()

# %%
test2005 = df_hurricanefinal.loc[df_hurricanefinal.Year == 2005].copy()
test2005 = test2005.drop(columns=['HURRICANE_COUNT',"VK08_TCCount", 'Year'],axis=1)
test2005 = pd.DataFrame(test2005)

# %%
test2020 = df_hurricanefinal.loc[df_hurricanefinal.Year == 2020].copy()
test2020 = test2020.drop(columns=['HURRICANE_COUNT',"VK08_TCCount", 'Year'],axis=1)
test2020 = pd.DataFrame(test2020)

# %%
test1999 = df_hurricanefinal.loc[df_hurricanefinal.Year == 1999].copy()
test1999 = test1999.drop(columns=['HURRICANE_COUNT',"VK08_TCCount", 'Year'],axis=1)
test1999 = pd.DataFrame(test1999)

# %%
test1999
# Out:
#      ERSSTv5_ASO_MDRRelative  ...  SahelPrecipIndex_JJAS_mean
# 129                 0.283575  ...                        2.64
#
# [1 rows x 12 columns]

# %%
#df_hurricanefinal1 = df_hurricanefinal.loc[df_hurricanefinal.Year != 2005]
df_hurricanefinal1 = df_hurricanefinal.loc[df_hurricanefinal.Year != 2020]
X = df_hurricanefinal1.drop(columns=['HURRICANE_COUNT',"VK08_TCCount", 'Year'],axis=1)
y = df_hurricanefinal1['HURRICANE_COUNT']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

test2005 = scaler.transform(test2005)
test2020 = scaler.transform(test2020)
test1999 = scaler.transform(test1999)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dropout
model = Sequential()
model.add(Dense(256,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128,activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
model.fit(x=X_train,y=y_train.values,
          validation_data=(X_test,y_test.values),
          batch_size=128,epochs=400, callbacks=[early_stop])
# Out:
# Epoch 1/400
# 1/1 [==============================] - 1s 657ms/step - loss: 110.6093 - val_loss: 100.0419
# Epoch 2/400
# 1/1 [==============================] - 0s 28ms/step - loss: 107.6625 - val_loss: 97.1180
# Epoch 3/400
# 1/1 [==============================] - 0s 30ms/step - loss: 104.5938 - val_loss: 93.8803
# Epoch 4/400
# 1/1 [==============================] - 0s 27ms/step - loss: 101.3991 - val_loss: 90.2717
# Epoch 5/400
# 1/1 [==============================] - 0s 31ms/step - loss: 97.7225 - val_loss: 86.2342
# Epoch 6/400
# 1/1 [==============================] - 0s 54ms/step - loss: 92.5198 - val_loss: 81.6928
# Epoch 7/400
# 1/1 [==============================] - 0s 47ms/step - loss: 87.9997 - val_loss: 76.5691
# Epoch 8/400
# 1/1 [==============================] - 0s 28ms/step - loss: 84.2370 - val_loss: 70.8375
# Epoch 9/400
# 1/1 [==============================] - 0s 33ms/step - loss: 77.4119 - val_loss: 64.5721
# Epoch 10/400
# 1/1 [==============================] - 0s 55ms/step - loss: 71.3506 - val_loss: 57.8692
# Epoch 11/400
# 1/1 [==============================] - 0s 34ms/step - loss: 66.2893 - val_loss: 50.8293
# Epoch 12/400
# 1/1 [==============================] - 0s 29ms/step - loss: 59.4060 - val_loss: 43.5493
# Epoch 13/400
# 1/1 [==============================] - 0s 31ms/step - loss: 51.7207 - val_loss: 36.1950
# Epoch 14/400
# 1/1 [==============================] - 0s 31ms/step - loss: 43.0271 - val_loss: 28.9829
# Epoch 15/400
# 1/1 [==============================] - 0s 31ms/step - loss: 36.6534 - val_loss: 22.2857
# Epoch 16/400
# 1/1 [==============================] - 0s 30ms/step - loss: 32.1944 - val_loss: 16.5417
# Epoch 17/400
# 1/1 [==============================] - 0s 33ms/step - loss: 27.4305 - val_loss: 12.4299
# Epoch 18/400
# 1/1 [==============================] - 0s 31ms/step - loss: 23.7776 - val_loss: 10.5956
# Epoch 19/400
# 1/1 [==============================] - 0s 29ms/step - loss: 20.2524 - val_loss: 11.3526
# Epoch 20/400
# 1/1 [==============================] - 0s 33ms/step - loss: 23.7871 - val_loss: 14.0474
# Epoch 21/400
# 1/1 [==============================] - 0s 34ms/step - loss: 23.5431 - val_loss: 17.0207
# Epoch 22/400
# 1/1 [==============================] - 0s 35ms/step - loss: 28.0764 - val_loss: 18.8026
# Epoch 23/400
# 1/1 [==============================] - 0s 32ms/step - loss: 33.7258 - val_loss: 18.5225
# Epoch 24/400
# 1/1 [==============================] - 0s 47ms/step - loss: 30.5999 - val_loss: 16.7176
# Epoch 25/400
# 1/1 [==============================] - 0s 39ms/step - loss: 29.6686 - val_loss: 14.3082
# Epoch 26/400
# 1/1 [==============================] - 0s 35ms/step - loss: 25.5732 - val_loss: 12.0845
# Epoch 27/400
# 1/1 [==============================] - 0s 32ms/step - loss: 23.5466 - val_loss: 10.4317
# Epoch 28/400
# 1/1 [==============================] - 0s 32ms/step - loss: 18.9801 - val_loss: 9.4881
# Epoch 29/400
# 1/1 [==============================] - 0s 32ms/step - loss: 21.9137 - val_loss: 9.1522
# Epoch 30/400
# 1/1 [==============================] - 0s 35ms/step - loss: 18.0854 - val_loss: 9.2912
# Epoch 31/400
# 1/1 [==============================] - 0s 27ms/step - loss: 20.2146 - val_loss: 9.7073
# Epoch 32/400
# 1/1 [==============================] - 0s 31ms/step - loss: 19.1607 - val_loss: 10.2051
# Epoch 33/400
# 1/1 [==============================] - 0s 31ms/step - loss: 19.2410 - val_loss: 10.6237
# Epoch 34/400
# 1/1 [==============================] - 0s 31ms/step - loss: 20.2357 - val_loss: 10.8582
# Epoch 35/400
# 1/1 [==============================] - 0s 33ms/step - loss: 20.4607 - val_loss: 10.8715
# Epoch 36/400
# 1/1 [==============================] - 0s 38ms/step - loss: 21.3804 - val_loss: 10.6807
# Epoch 37/400
# 1/1 [==============================] - 0s 46ms/step - loss: 21.0767 - val_loss: 10.2969
# Epoch 38/400
# 1/1 [==============================] - 0s 30ms/step - loss: 21.1950 - val_loss: 9.7800
# Epoch 39/400
# 1/1 [==============================] - 0s 30ms/step - loss: 18.6146 - val_loss: 9.1669
# Epoch 00039: early stopping

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()

# %%
predictions2005 = model.predict(test2005)
predictions2020 = model.predict(test2020)
predictions1999 = model.predict(test1999)

# %%
predictions1999
# Out:
# array([[10.547104]], dtype=float32)
