# %%
import pandas as pd
from google.colab import files
import io
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Cleaning and Pre-Processing

# %%
df_AMM_JJASOM_mean = pd.read_table('./Data/AMM_JJASOM_mean_1950-2020.dat', sep="\s+", header=None)
df_AMM_JJASOM_mean = df_AMM_JJASOM_mean.rename(columns={0: "Year", 1:"AMM_JJASOM_mean"}).copy()
df_AMM_JJASOM_mean
# Out:
#     Year  AMM_JJASOM_mean
# 0   1950         1.016667
# 1   1951         0.916667
# 2   1952         2.373333
# 3   1953         1.163333
# 4   1954        -0.635000
# ..   ...              ...
# 66  2016         1.530000
# 67  2017         2.618333
# 68  2018        -2.171667
# 69  2019         0.566667
# 70  2020         1.467830
#
# [71 rows x 2 columns]

# %%
df_ERSSTv5_ASO_MDRRelative = pd.read_table('./Data/ERSSTv5_ASO_MDRRelative_SST_1870-2020.dat', sep="\s+", header=None)
df_ERSSTv5_ASO_MDRRelative
# Out:
#             0
# 0    0.239469
# 1   -0.396031
# 2   -0.743195
# 3   -0.021984
# 4    0.161659
# ..        ...
# 146  0.082054
# 147  0.221386
# 148 -0.232869
# 149 -0.098519
# 150  0.183437
#
# [151 rows x 1 columns]

# %%
df_ERSSTv5_ASO_MDR = pd.read_table('./Data/ERSSTv5_ASO_MDR_SST_1870-2020.dat', sep="\s+", header=None)
df_ERSSTv5_ASO_MDR
# Out:
#             0
# 0    27.65656
# 1    27.01905
# 2    26.62783
# 3    27.38899
# 4    27.44587
# ..        ...
# 146  28.36498
# 147  28.43985
# 148  27.93210
# 149  28.12645
# 150  28.35310
#
# [151 rows x 1 columns]

# %%
df_ERSSTv5_ASO_MDR_anomalies = pd.read_table('./Data/ERSSTv5_ASO_MDR_SST_anomalies_1870-2020.dat', sep="\s+", header=None)
df_ERSSTv5_ASO_MDR_anomalies
# Out:
#             0
# 0   -0.233739
# 1   -0.871247
# 2   -1.262471
# 3   -0.501313
# 4   -0.444434
# ..        ...
# 146  0.474681
# 147  0.549548
# 148  0.041802
# 149  0.236148
# 150  0.462798
#
# [151 rows x 1 columns]

# %%
df_ERSSTv5_ASO_MDR_tropics = pd.read_table('./Data/ERSSTv5_ASO_tropics_SST_1870-2020.dat', sep="\s+", header=None)
df_ERSSTv5_ASO_MDR_tropics
# Out:
#             0
# 0    25.89209
# 1    25.89008
# 2    25.84602
# 3    25.88597
# 4    25.75921
# ..        ...
# 146  26.75793
# 147  26.69346
# 148  26.63997
# 149  26.69997
# 150  26.64466
#
# [151 rows x 1 columns]

# %%
df_ERSSTv5_ASO_MDR_tropics_anomalies = pd.read_table('./Data/ERSSTv5_ASO_tropics_SST_anomalies_1870-2020.dat', sep="\s+", header=None)
df_ERSSTv5_ASO_MDR_tropics_anomalies
# Out:
#             0
# 0   -0.473208
# 1   -0.475217
# 2   -0.519276
# 3   -0.479329
# 4   -0.606093
# ..        ...
# 146  0.392627
# 147  0.328162
# 148  0.274671
# 149  0.334666
# 150  0.279361
#
# [151 rows x 1 columns]

# %%
df_HURDAT_TCCounts = pd.read_table('./Data/HURDAT_TCCounts_1870-2020.dat', sep="\s+", header=None)
df_HURDAT_TCCounts
# Out:
#         0   1
# 0    1870  11
# 1    1871   8
# 2    1872   5
# 3    1873   5
# 4    1874   7
# ..    ...  ..
# 146  2016  15
# 147  2017  17
# 148  2018  15
# 149  2019  18
# 150  2020  30
#
# [151 rows x 2 columns]

# %%
df_NAO_DJFM_mean = pd.read_table('./Data/NAO_DJFM_mean_1870-2020.dat', sep="\s+", header=None)
df_NAO_DJFM_mean
# Out:
#         0        1
# 0    1870  0.00275
# 1    1871  0.05475
# 2    1872  0.24850
# 3    1873  1.77750
# 4    1874 -0.53575
# ..    ...      ...
# 146  2016  1.17500
# 147  2017  0.39925
# 148  2018  1.46525
# 149  2019  2.22850
# 150  2020 -0.13500
#
# [151 rows x 2 columns]

# %%
df_NAO_MJ_mean = pd.read_table('./Data/NAO_MJ_mean_1870-2020.dat', sep="\s+", header=None)
df_NAO_MJ_mean
# Out:
#         0       1
# 0    1870  1.0530
# 1    1871 -1.9325
# 2    1872 -0.1640
# 3    1873 -0.0725
# 4    1874 -1.3055
# ..    ...     ...
# 146  2016 -1.0485
# 147  2017 -0.0835
# 148  2018  0.3060
# 149  2019 -0.3895
# 150  2020 -0.8060
#
# [151 rows x 2 columns]

# %%
df_Nino12_DJF = pd.read_table('./Data/Nino12_DJF_1870-2020.dat', sep="\s+", header=None)
df_Nino12_DJF
# Out:
#         0         1
# 0    1870 -0.850000
# 1    1871 -1.156667
# 2    1872 -1.003333
# 3    1873 -1.156667
# 4    1874 -0.676667
# ..    ...       ...
# 146  2016  0.423333
# 147  2017 -1.073333
# 148  2018  0.706667
# 149  2019 -0.113333
# 150  2020 -0.633000
#
# [151 rows x 2 columns]

# %%
df_Nino34_DJF = pd.read_table('./Data/Nino34_DJF_1870-2020.dat', sep="\s+", header=None)
df_Nino34_DJF
# Out:
#         0         1
# 0    1870 -0.540000
# 1    1871 -0.640000
# 2    1872 -0.890000
# 3    1873 -0.896667
# 4    1874 -0.740000
# ..    ...       ...
# 146  2016 -0.286667
# 147  2017 -0.813333
# 148  2018  0.700000
# 149  2019  0.543333
# 150  2020 -0.987000
#
# [151 rows x 2 columns]

# %%
df_Nino3_DJF = pd.read_table('./Data/Nino3_DJF_1870-2020.dat', sep="\s+", header=None)
df_Nino3_DJF
# Out:
#         0         1
# 0    1870 -0.573333
# 1    1871 -0.710000
# 2    1872 -1.046667
# 3    1873 -1.276667
# 4    1874 -0.793333
# ..    ...       ...
# 146  2016 -0.056667
# 147  2017 -1.010000
# 148  2018  0.720000
# 149  2019  0.273333
# 150  2020 -0.650000
#
# [151 rows x 2 columns]

# %%
df_SahelPrecipIndex_JJAS_mean = pd.read_table('./Data/SahelPrecipIndex_JJAS_mean_1901-2017.dat', sep="\s+", header=None)
df_SahelPrecipIndex_JJAS_mean = df_SahelPrecipIndex_JJAS_mean.rename(columns={0: "Year", 1:"SahelPrecipIndex_JJAS_mean"}).copy()

# %%
df_SahelPrecipIndex_JJAS_mean
# Out:
#      Year  SahelPrecipIndex_JJAS_mean
# 0    1901                      3.7100
# 1    1902                      0.1200
# 2    1903                      2.0825
# 3    1904                      0.9850
# 4    1905                      2.5625
# ..    ...                         ...
# 112  2013                      0.6425
# 113  2014                      0.5050
# 114  2015                      3.0375
# 115  2016                      2.5250
# 116  2017                      1.2625
#
# [117 rows x 2 columns]

# %%
df_VK08_TCCount = pd.read_table('./Data/VK08_TCCounts_1878-2020.dat', sep="\s+", header=None)
df_VK08_TCCount = df_VK08_TCCount.rename(columns={0: "Year", 1:"VK08_TCCount"}).copy()
df_VK08_TCCount
# Out:
#      Year  VK08_TCCount
# 0    1878        15.370
# 1    1879        11.308
# 2    1880        14.084
# 3    1881        10.234
# 4    1882         9.183
# ..    ...           ...
# 138  2016        15.000
# 139  2017        17.000
# 140  2018        15.000
# 141  2019        18.000
# 142  2020        30.000
#
# [143 rows x 2 columns]

# %%
df_hurricanefinal = pd.DataFrame()

# %%
df_hurricanefinal['Year'] = df_HURDAT_TCCounts[0]
df_hurricanefinal['HURRICANE_COUNT'] = df_HURDAT_TCCounts[1]

df_hurricanefinal['ERSSTv5_ASO_MDRRelative'] = df_ERSSTv5_ASO_MDRRelative[0]
df_hurricanefinal['ERSSTv5_ASO_MDR'] = df_ERSSTv5_ASO_MDR[0] 
df_hurricanefinal['ERSSTv5_ASO_MDR_anomalies'] = df_ERSSTv5_ASO_MDR_anomalies[0] 
df_hurricanefinal['ERSSTv5_ASO_MDR_tropics'] = df_ERSSTv5_ASO_MDR_tropics[0] 
df_hurricanefinal['ERSSTv5_ASO_MDR_tropics_anomalies'] = df_ERSSTv5_ASO_MDR_tropics_anomalies[0] 
df_hurricanefinal['ERSSTv5_ASO_MDR'] = df_ERSSTv5_ASO_MDR[0] 

df_hurricanefinal['NAO_DJFM_mean'] = df_NAO_DJFM_mean[1]
df_hurricanefinal['NAO_MJ_mean'] = df_NAO_MJ_mean[1] 

df_hurricanefinal['Nino12_DJF'] = df_Nino12_DJF[1]
df_hurricanefinal['Nino34_DJF'] = df_Nino34_DJF[1] 
df_hurricanefinal['Nino3_DJF'] = df_Nino3_DJF[1]

# %%
df_hurricanefinal = pd.merge(df_hurricanefinal, df_AMM_JJASOM_mean,how = "left", on=['Year'])
df_hurricanefinal = pd.merge(df_hurricanefinal, df_VK08_TCCount,how = "left", on=['Year'])
df_hurricanefinal = pd.merge(df_hurricanefinal, df_SahelPrecipIndex_JJAS_mean,how = "left", on=['Year'])

# %%
df_hurricanefinal
# Out:
#      Year  HURRICANE_COUNT  ...  VK08_TCCount  SahelPrecipIndex_JJAS_mean
# 0    1870               11  ...           NaN                         NaN
# 1    1871                8  ...           NaN                         NaN
# 2    1872                5  ...           NaN                         NaN
# 3    1873                5  ...           NaN                         NaN
# 4    1874                7  ...           NaN                         NaN
# ..    ...              ...  ...           ...                         ...
# 146  2016               15  ...          15.0                      2.5250
# 147  2017               17  ...          17.0                      1.2625
# 148  2018               15  ...          15.0                         NaN
# 149  2019               18  ...          18.0                         NaN
# 150  2020               30  ...          30.0                         NaN
#
# [151 rows x 15 columns]

# %%
df_hurricanefinalVK08Counts = df_hurricanefinal.dropna(subset=['VK08_TCCount'])

# %%
fig = plt.figure(figsize =(10, 7))
# Creating plot
plt.boxplot(df_hurricanefinalVK08Counts['VK08_TCCount'])
# show plot
plt.show()

# %%
df_hurricanefinalVK08Counts.head(70)
# Out:
#     Year  HURRICANE_COUNT  ...  VK08_TCCount  SahelPrecipIndex_JJAS_mean
# 8   1878               12  ...        15.370                         NaN
# 9   1879                8  ...        11.308                         NaN
# 10  1880               11  ...        14.084                         NaN
# 11  1881                7  ...        10.234                         NaN
# 12  1882                6  ...         9.183                         NaN
# ..   ...              ...  ...           ...                         ...
# 73  1943               10  ...        11.960                      3.0675
# 74  1944               11  ...        12.556                      0.1775
# 75  1945               11  ...        13.077                      2.8950
# 76  1946                6  ...         7.710                      2.1600
# 77  1947                9  ...        10.188                      1.2575
#
# [70 rows x 15 columns]

# %% [markdown]
# #XG BOOST

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split 
from sklearn.metrics import mean_squared_error as MSE 
import matplotlib.pyplot as plt
# !pip install eli5
from eli5 import show_weights
from eli5 import explain_prediction
from IPython.display import display
import eli5
from sklearn.model_selection import GridSearchCV
# Out:
# Requirement already satisfied: eli5 in /usr/local/lib/python3.7/dist-packages (0.11.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from eli5) (2.11.3)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from eli5) (0.8.9)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from eli5) (1.15.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from eli5) (1.4.1)
# Requirement already satisfied: attrs>16.0.0 in /usr/local/lib/python3.7/dist-packages (from eli5) (21.4.0)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.7/dist-packages (from eli5) (1.0.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (from eli5) (0.10.1)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from eli5) (1.21.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20->eli5) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20->eli5) (3.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->eli5) (2.0.1)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
test2005 = df_hurricanefinalVK08Counts.loc[df_hurricanefinalVK08Counts.Year == 2005].drop(columns=['HURRICANE_COUNT',"VK08_TCCount", 'Year'],axis=1)
test2020 = df_hurricanefinalVK08Counts.loc[df_hurricanefinalVK08Counts.Year == 2020].drop(columns=['HURRICANE_COUNT',"VK08_TCCount", 'Year'],axis=1)
test1999 = df_hurricanefinalVK08Counts.loc[df_hurricanefinalVK08Counts.Year == 1999].drop(columns=['HURRICANE_COUNT',"VK08_TCCount", 'Year'],axis=1)

# %%
df_hurricanefinal1 = df_hurricanefinalVK08Counts.loc[df_hurricanefinal.Year != 2005]
#df_hurricanefinal1 = df_hurricanefinal1.loc[df_hurricanefinal.Year != 2020]

X = df_hurricanefinal1.drop(columns=['HURRICANE_COUNT',"VK08_TCCount", 'Year'],axis=1)
y = df_hurricanefinal1['VK08_TCCount']
#outliers across all years
#3- fold cross validation - see which years we under predicted
# Splitting 
train_X, test_X, train_y, test_y = train_test_split(X, y, 
                      test_size = 0.3) 
  
# Instantiation 
xgb_r = xgb.XGBRegressor(objective ='reg:linear', 
                  n_estimators = 10) 
  
# Fitting the model 
xgb_r.fit(train_X, train_y) 
  
# Predict the model 
pred = xgb_r.predict(test_X) 
  
# RMSE Computation 
rmse = mean_absolute_error(test_y,pred)

print("MAE : % f" %(rmse))
# Out:
# [18:33:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# MAE :  3.706727

# %%
dtrain = xgb.DMatrix(train_X, label=train_y)
dtest = xgb.DMatrix(test_X, label=test_y)

# %%
num_boost_round = 999

# %%
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'min_child_weight': [.05,1,1.5,2],
           'n_estimators': [100, 500, 1000],
           'gamma': [0,.5,1,2],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_squared_error', 
                   verbose=1)
clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest RMSE: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 864 candidates, totalling 4320 fits
# [18:33:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:33:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:34:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...
# [18:41:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:41:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Best parameters: {'colsample_bytree': 0.3, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 3, 'min_child_weight': 0.05, 'n_estimators': 100}
# Lowest RMSE:  3.899344039971379

# %%
params = {'colsample_bytree': 0.3, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 3, 'min_child_weight': 0.05, 'n_estimators': 100}
params['eval_metric'] = "mae"

# %%
xgmodel = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)
# Out:
# [0]	Test-mae:8.81718
# Will train until Test-mae hasn't improved in 10 rounds.
# [1]	Test-mae:8.37207
# [2]	Test-mae:7.95035
# [3]	Test-mae:7.55067
# [4]	Test-mae:7.15523
# [5]	Test-mae:6.75965
# [6]	Test-mae:6.41393
# [7]	Test-mae:6.06611
# [8]	Test-mae:5.78402
# [9]	Test-mae:5.48447
# [10]	Test-mae:5.21978
# [11]	Test-mae:4.96108
# [12]	Test-mae:4.74227
# [13]	Test-mae:4.50584
# [14]	Test-mae:4.30134
# [15]	Test-mae:4.09197
# [16]	Test-mae:3.88832
# [17]	Test-mae:3.7213
# [18]	Test-mae:3.55812
# [19]	Test-mae:3.39018
# [20]	Test-mae:3.22258
# [21]	Test-mae:3.10152
# [22]	Test-mae:2.97266
# [23]	Test-mae:2.86883
# [24]	Test-mae:2.76319
# [25]	Test-mae:2.68832
# [26]	Test-mae:2.58847
# [27]	Test-mae:2.5021
# [28]	Test-mae:2.41716
# [29]	Test-mae:2.3266
# [30]	Test-mae:2.25557
# [31]	Test-mae:2.18299
# [32]	Test-mae:2.11729
# [33]	Test-mae:2.04419
# [34]	Test-mae:2.00761
# [35]	Test-mae:1.97055
# [36]	Test-mae:1.93141
# [37]	Test-mae:1.90213
# [38]	Test-mae:1.86868
# [39]	Test-mae:1.84569
# [40]	Test-mae:1.83263
# [41]	Test-mae:1.82258
# [42]	Test-mae:1.8051
# [43]	Test-mae:1.78302
# [44]	Test-mae:1.76221
# [45]	Test-mae:1.7552
# [46]	Test-mae:1.73559
# [47]	Test-mae:1.72335
# [48]	Test-mae:1.71444
# [49]	Test-mae:1.70097
# [50]	Test-mae:1.70211
# [51]	Test-mae:1.69314
# [52]	Test-mae:1.68919
# [53]	Test-mae:1.69004
# [54]	Test-mae:1.68588
# [55]	Test-mae:1.68229
# [56]	Test-mae:1.68903
# [57]	Test-mae:1.6838
# [58]	Test-mae:1.69186
# [59]	Test-mae:1.68587
# [60]	Test-mae:1.68338
# [61]	Test-mae:1.68067
# [62]	Test-mae:1.68355
# [63]	Test-mae:1.68494
# [64]	Test-mae:1.6811
# [65]	Test-mae:1.68926
# [66]	Test-mae:1.70067
# [67]	Test-mae:1.69531
# [68]	Test-mae:1.69481
# [69]	Test-mae:1.70419
# [70]	Test-mae:1.70501
# [71]	Test-mae:1.69679
# Stopping. Best iteration:
# [61]	Test-mae:1.68067

# %%
show_weights(xgmodel)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1356
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ERSSTv5_ASO_MDR
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 81.56%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1208
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ERSSTv5_ASO_MDR_anomalies
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 82.68%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1104
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ERSSTv5_ASO_MDRRelative
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0984
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ERSSTv5_ASO_MDR_tropics_anomalies
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.83%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0914
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Nino34_DJF
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0814
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Nino3_DJF
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0813
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AMM_JJASOM_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.58%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0686
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ERSSTv5_ASO_MDR_tropics
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.68%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0601
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 SahelPrecipIndex_JJAS_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0572
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Nino12_DJF
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0508
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NAO_DJFM_mean
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.89%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0441
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NAO_MJ_mean
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
plt.rcParams['figure.figsize'] = [25, 12.5]

# %%
xgb.plot_importance(xgmodel, max_num_features=25)
plt.rcParams['figure.figsize'] = [5, 5]
plt.show()

# %%
xgb.plot_tree(xgmodel)

# %%
explain_prediction(xgmodel, test2005.iloc[0])
# Out:
# Explanation(estimator='<xgboost.core.Booster object at 0x7f39472c6d90>', description='\nFeatures with largest coefficients.\n\nFeature weights are calculated by following decision paths in trees\nof an ensemble. Each leaf has an output score, and expected scores can also be\nassigned to parent nodes. Contribution of one feature on the decision path\nis how much expected score changes from parent to child. Weights of all \nfeatures sum to the output score of the estimator.\n\nCaveats:\n1. Feature weights just show if the feature contributed positively or\n   negatively to the final score, and does not show how increasing or\n   decreasing the feature value will change the prediction.\n2. In some cases, feature weight can be close to zero for an important feature.\n   For example, in a single tree that computes XOR function, the feature at the\n   top of the tree will have zero weight because expected scores for both\n   branches are equal, so decision at the top feature does not change the\n   expected score. For an ensemble predicting XOR functions it might not be\n   a problem, but it is not reliable if most trees happen to choose the same\n   feature at the top.\n', error=None, method='decision paths', is_regression=True, targets=[TargetExplanation(target='y', feature_weights=FeatureWeights(pos=[FeatureWeight(feature='<BIAS>', weight=10.00001876137182, std=None, value=1.0), FeatureWeight(feature='ERSSTv5_ASO_MDR', weight=1.7458380812938692, std=None, value=28.43595), FeatureWeight(feature='Nino34_DJF', weight=1.1639765474932346, std=None, value=-0.813333333), FeatureWeight(feature='ERSSTv5_ASO_MDRRelative', weight=0.9370208680149298, std=None, value=0.4560429), FeatureWeight(feature='ERSSTv5_ASO_MDR_tropics', weight=0.6292358426806026, std=None, value=26.4549), FeatureWeight(feature='ERSSTv5_ASO_MDR_anomalies', weight=0.5708963963070194, std=None, value=0.5456474), FeatureWeight(feature='Nino12_DJF', weight=0.5658931606385265, std=None, value=-0.516666667), FeatureWeight(feature='ERSSTv5_ASO_MDR_tropics_anomalies', weight=0.45275078277542025, std=None, value=0.08960456), FeatureWeight(feature='AMM_JJASOM_mean', weight=0.36855231394889365, std=None, value=4.048333333), FeatureWeight(feature='Nino3_DJF', weight=0.2955370552049097, std=None, value=-0.856666667), FeatureWeight(feature='NAO_DJFM_mean', weight=0.16373605647272818, std=None, value=-0.81775), FeatureWeight(feature='NAO_MJ_mean', weight=0.09403377991662701, std=None, value=-0.5675)], neg=[FeatureWeight(feature='SahelPrecipIndex_JJAS_mean', weight=-0.09298193664857941, std=None, value=0.4725)], pos_remaining=0, neg_remaining=0), proba=None, score=16.894507709470005, weighted_spans=None, heatmap=None)], feature_importances=None, decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
explain_prediction(xgmodel, test2020.iloc[0])
# Out:
# Explanation(estimator='<xgboost.core.Booster object at 0x7f39472c6d90>', description='\nFeatures with largest coefficients.\n\nFeature weights are calculated by following decision paths in trees\nof an ensemble. Each leaf has an output score, and expected scores can also be\nassigned to parent nodes. Contribution of one feature on the decision path\nis how much expected score changes from parent to child. Weights of all \nfeatures sum to the output score of the estimator.\n\nCaveats:\n1. Feature weights just show if the feature contributed positively or\n   negatively to the final score, and does not show how increasing or\n   decreasing the feature value will change the prediction.\n2. In some cases, feature weight can be close to zero for an important feature.\n   For example, in a single tree that computes XOR function, the feature at the\n   top of the tree will have zero weight because expected scores for both\n   branches are equal, so decision at the top feature does not change the\n   expected score. For an ensemble predicting XOR functions it might not be\n   a problem, but it is not reliable if most trees happen to choose the same\n   feature at the top.\n', error=None, method='decision paths', is_regression=True, targets=[TargetExplanation(target='y', feature_weights=FeatureWeights(pos=[FeatureWeight(feature='<BIAS>', weight=10.00001876137182, std=None, value=1.0), FeatureWeight(feature='Nino34_DJF', weight=2.534528452365364, std=None, value=-0.987), FeatureWeight(feature='ERSSTv5_ASO_MDR', weight=2.2480540142144667, std=None, value=28.3531), FeatureWeight(feature='ERSSTv5_ASO_MDRRelative', weight=1.8379138478752834, std=None, value=0.183437), FeatureWeight(feature='ERSSTv5_ASO_MDR_tropics', weight=1.4907031411612943, std=None, value=26.64466), FeatureWeight(feature='AMM_JJASOM_mean', weight=0.8378159013853383, std=None, value=1.46783), FeatureWeight(feature='Nino12_DJF', weight=0.7788425706072972, std=None, value=-0.633), FeatureWeight(feature='Nino3_DJF', weight=0.7284414021852189, std=None, value=-0.65), FeatureWeight(feature='ERSSTv5_ASO_MDR_anomalies', weight=0.7108670600070194, std=None, value=0.4627979), FeatureWeight(feature='ERSSTv5_ASO_MDR_tropics_anomalies', weight=0.7029769007460308, std=None, value=0.2793609), FeatureWeight(feature='SahelPrecipIndex_JJAS_mean', weight=0.6225755937463291, std=None, value=nan), FeatureWeight(feature='NAO_MJ_mean', weight=0.2862240913689544, std=None, value=-0.806), FeatureWeight(feature='NAO_DJFM_mean', weight=0.17435597086558532, std=None, value=-0.135)], neg=[], pos_remaining=0, neg_remaining=0), proba=None, score=22.9533177079, weighted_spans=None, heatmap=None)], feature_importances=None, decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
explain_prediction(xgmodel, test1999.iloc[0])
# Out:
# Explanation(estimator='<xgboost.core.Booster object at 0x7f39472c6d90>', description='\nFeatures with largest coefficients.\n\nFeature weights are calculated by following decision paths in trees\nof an ensemble. Each leaf has an output score, and expected scores can also be\nassigned to parent nodes. Contribution of one feature on the decision path\nis how much expected score changes from parent to child. Weights of all \nfeatures sum to the output score of the estimator.\n\nCaveats:\n1. Feature weights just show if the feature contributed positively or\n   negatively to the final score, and does not show how increasing or\n   decreasing the feature value will change the prediction.\n2. In some cases, feature weight can be close to zero for an important feature.\n   For example, in a single tree that computes XOR function, the feature at the\n   top of the tree will have zero weight because expected scores for both\n   branches are equal, so decision at the top feature does not change the\n   expected score. For an ensemble predicting XOR functions it might not be\n   a problem, but it is not reliable if most trees happen to choose the same\n   feature at the top.\n', error=None, method='decision paths', is_regression=True, targets=[TargetExplanation(target='y', feature_weights=FeatureWeights(pos=[FeatureWeight(feature='<BIAS>', weight=10.00001876137182, std=None, value=1.0), FeatureWeight(feature='Nino34_DJF', weight=0.9609796430719861, std=None, value=-1.62), FeatureWeight(feature='ERSSTv5_ASO_MDRRelative', weight=0.8380049705139493, std=None, value=0.2835747), FeatureWeight(feature='ERSSTv5_ASO_MDR', weight=0.21442262421789857, std=None, value=27.93422), FeatureWeight(feature='ERSSTv5_ASO_MDR_anomalies', weight=0.1608355575037868, std=None, value=0.04391745), FeatureWeight(feature='Nino3_DJF', weight=0.07051113131641083, std=None, value=-1.44), FeatureWeight(feature='SahelPrecipIndex_JJAS_mean', weight=0.01057278242005764, std=None, value=2.64)], neg=[FeatureWeight(feature='NAO_MJ_mean', weight=-1.0273218972923055, std=None, value=1.2065), FeatureWeight(feature='ERSSTv5_ASO_MDR_tropics_anomalies', weight=-0.2594285918509941, std=None, value=-0.2396572), FeatureWeight(feature='ERSSTv5_ASO_MDR_tropics', weight=-0.25056259979809126, std=None, value=26.12564), FeatureWeight(feature='AMM_JJASOM_mean', weight=-0.1053520488678427, std=None, value=0.975), FeatureWeight(feature='NAO_DJFM_mean', weight=-0.09515695880070556, std=None, value=1.84575), FeatureWeight(feature='Nino12_DJF', weight=-0.08012993669696848, std=None, value=-0.806666667)], pos_remaining=0, neg_remaining=0), proba=None, score=10.437393437109, weighted_spans=None, heatmap=None)], feature_importances=None, decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %% [markdown]
# # 4 Neuron Neural Network

# %%
df_hurricanefinal = df_hurricanefinal.fillna(0).copy()

# %% [markdown]
# ### Gathering Test Years

# %%
test2005 = df_hurricanefinal.loc[df_hurricanefinal.Year == 2005].copy()
test2005 = test2005.drop(columns=['HURRICANE_COUNT',"VK08_TCCount", 'Year'],axis=1)
test2005 = pd.DataFrame(test2005)

# %%
test2020 = df_hurricanefinal.loc[df_hurricanefinal.Year == 2020].copy()
test2020 = test2020.drop(columns=['HURRICANE_COUNT',"VK08_TCCount", 'Year'],axis=1)
test2020 = pd.DataFrame(test2020)

# %%
test1999 = df_hurricanefinal.loc[df_hurricanefinal.Year == 1999].copy()
test1999 = test1999.drop(columns=['HURRICANE_COUNT',"VK08_TCCount", 'Year'],axis=1)
test1999 = pd.DataFrame(test1999)

# %% [markdown]
# ###Data Scaling

# %%
#df_hurricanefinal1 = df_hurricanefinal.loc[df_hurricanefinal.Year != 2005]
df_hurricanefinal1 = df_hurricanefinal.loc[df_hurricanefinal.Year != 2020]
X = df_hurricanefinal1.drop(columns=['HURRICANE_COUNT',"VK08_TCCount", 'Year'],axis=1)
y = df_hurricanefinal1['HURRICANE_COUNT']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

test2005 = scaler.transform(test2005)
test2020 = scaler.transform(test2020)
test1999 = scaler.transform(test1999)

# %% [markdown]
# ### Model Creation and Training

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dropout

# %%
model = Sequential()
model.add(Dense(2,activation='relu'))
model.add(Dense(2,activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mae')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
model.fit(x=X_train,y=y_train.values,
          validation_data=(X_test,y_test.values),
          batch_size=128,epochs=10000, callbacks=[early_stop])
# Out:
# Epoch 1/10000
# 1/1 [==============================] - 1s 751ms/step - loss: 9.5458 - val_loss: 9.5254
# Epoch 2/10000
# 1/1 [==============================] - 0s 38ms/step - loss: 9.5434 - val_loss: 9.5233
# Epoch 3/10000
# 1/1 [==============================] - 0s 30ms/step - loss: 9.5411 - val_loss: 9.5212
# Epoch 4/10000
# 1/1 [==============================] - 0s 33ms/step - loss: 9.5387 - val_loss: 9.5190
# Epoch 5/10000
# 1/1 [==============================] - 0s 29ms/step - loss: 9.5363 - val_loss: 9.5167
# Epoch 6/10000
# 1/1 [==============================] - 0s 34ms/step - loss: 9.5338 - val_loss: 9.5144
# Epoch 7/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 9.5314 - val_loss: 9.5120
# Epoch 8/10000
# 1/1 [==============================] - 0s 30ms/step - loss: 9.5288 - val_loss: 9.5096
# Epoch 9/10000
# 1/1 [==============================] - 0s 32ms/step - loss: 9.5262 - val_loss: 9.5071
# Epoch 10/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 9.5235 - val_loss: 9.5046
# Epoch 11/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 9.5208 - val_loss: 9.5021
# Epoch 12/10000
# 1/1 [==============================] - 0s 33ms/step - loss: 9.5180 - val_loss: 9.4996
# Epoch 13/10000
# 1/1 [==============================] - 0s 35ms/step - loss: 9.5152 - val_loss: 9.4971
# Epoch 14/10000
# 1/1 [==============================] - 0s 32ms/step - loss: 9.5123 - val_loss: 9.4945
# Epoch 15/10000
# 1/1 [==============================] - 0s 38ms/step - loss: 9.5094 - val_loss: 9.4919
# Epoch 16/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 9.5064 - val_loss: 9.4892
# Epoch 17/10000
# 1/1 [==============================] - 0s 85ms/step - loss: 9.5033 - val_loss: 9.4863
# Epoch 18/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 9.5001 - val_loss: 9.4833
# Epoch 19/10000
# 1/1 [==============================] - 0s 92ms/step - loss: 9.4969 - val_loss: 9.4801
# Epoch 20/10000
# 1/1 [==============================] - 0s 47ms/step - loss: 9.4935 - val_loss: 9.4767
# Epoch 21/10000
# 1/1 [==============================] - 0s 52ms/step - loss: 9.4901 - val_loss: 9.4733
# Epoch 22/10000
# 1/1 [==============================] - 0s 39ms/step - loss: 9.4866 - val_loss: 9.4698
# Epoch 23/10000
# 1/1 [==============================] - 0s 59ms/step - loss: 9.4828 - val_loss: 9.4663
# Epoch 24/10000
# 1/1 [==============================] - 0s 42ms/step - loss:
10000
# 1/1 [==============================] - 0s 42ms/step - loss: 8.4053 - val_loss: 8.3772
# Epoch 123/10000
# 1/1 [==============================] - 0s 118ms/step - loss: 8.3877 - val_loss: 8.3589
# Epoch 124/10000
# 1/1 [==============================] - 0s 39ms/step - loss: 8.3700 - val_loss: 8.3405
# Epoch 125/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 8.3521 - val_loss: 8.3219
# Epoch 126/10000
# 1/1 [==============================] - 0s 44ms/step - loss: 8.3342 - val_loss: 8.3032
# Epoch 127/10000
# 1/1 [==============================] - 0s 54ms/step - loss: 8.3161 - val_loss: 8.2844
# Epoch 128/10000
# 1/1 [==============================] - 0s 51ms/step - loss: 8.2979 - val_loss: 8.2655
# Epoch 129/10000
# 1/1 [==============================] - 0s 59ms/step - loss: 8.2796 - val_loss: 8.2465
# Epoch 130/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 8.2612 - val_loss: 8.2273
# Epoch 131/10000
# 1/1 [==============================] - 0s 124ms/step - loss: 8.2426 - val_loss: 8.2080
# Epoch 132/10000
# 1/1 [==============================] - 0s 70ms/step - loss: 8.2240 - val_loss: 8.1886
# Epoch 133/10000
# 1/1 [==============================] - 0s 50ms/step - loss: 8.2052 - val_loss: 8.1691
# Epoch 134/10000
# 1/1 [==============================] - 0s 89ms/step - loss: 8.1863 - val_loss: 8.1494
# Epoch 135/10000
# 1/1 [==============================] - 0s 40ms/step - loss: 8.1673 - val_loss: 8.1296
# Epoch 136/10000
# 1/1 [==============================] - 0s 60ms/step - loss: 8.1481 - val_loss: 8.1096
# Epoch 137/10000
# 1/1 [==============================] - 0s 72ms/step - loss: 8.1291 - val_loss: 8.0896
# Epoch 138/10000
# 1/1 [==============================] - 0s 40ms/step - loss: 8.1102 - val_loss: 8.0695
# Epoch 139/10000
# 1/1 [==============================] - 0s 53ms/step - loss: 8.0912 - val_loss: 8.0493
# Epoch 140/10000
# 1/1 [==============================] - 0s 69ms/step - loss: 8.0721 - val_loss: 8.0289
# Epoch 141/10000
# 1/1 [==============================] - 0s 45ms/step - loss: 8.0529 - val_loss: 8.0085
# Epoch 142/10000
# 1/1 [==============================] - 0s 66ms/step - loss: 8.0336 - val_loss: 7.9880
# Epoch 143/10000
# 1/1 [==============================] - 0s 45ms/step - loss: 8.0142 - val_loss: 7.9673
# Epoch 144/10000
# 1/1 [==============================] - 0s 79ms/step - loss: 7.9947 - val_loss: 7.9465
# Epoch 145/10000
# 1/1 [==============================] - 0s 80ms/step - loss: 7.9750 - val_loss: 7.9256
# Epoch 146/10000
# 1/1 [==============================] - 0s 67ms/step - loss: 7.9553 - val_loss: 7.9046
# Epoch 147/10000
# 1/1 [==============================] - 0s 87ms/step - loss: 7.9355 - val_loss: 7.8834
# Epoch 148/10000
# 1/1 [==============================] - 0s 101ms/step - loss: 7.9155 - val_loss: 7.8621
# Epoch 149/10000
# 1/1 [==============================] - 0s 44ms/step - loss: 7.8954 - val_loss: 7.8407
# Epoch 150/10000
# 1/1 [==============================] - 0s 56ms/step - loss: 7.8752 - val_loss: 7.8192
# Epoch 151/10000
# 1/1 [==============================] - 0s 45ms/step - loss: 7.8548 - val_loss: 7.7975
# Epoch 152/10000
# 1/1 [==============================] - 0s 42ms/step - loss: 7.8344 - val_loss: 7.7767
# Epoch 153/10000
# 1/1 [==============================] - 0s 48ms/step - loss: 7.8138 - val_loss: 7.7557
# Epoch 154/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 7.7931 - val_loss: 7.7346
# Epoch 155/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 7.7722 - val_loss: 7.7134
# Epoch 156/10000
# 1/1 [==============================] - 0s 76ms/step - loss: 7.7513 - val_loss: 7.6921
# Epoch 157/10000
# 1/1 [==============================] - 0s 76ms/step - loss: 7.7302 - val_loss: 7.6706
# Epoch 158/10000
# 1/1 [==============================] - 0s 78ms/step - loss:
10000
# 1/1 [==============================] - 0s 77ms/step - loss: 3.6205 - val_loss: 2.8392
# Epoch 427/10000
# 1/1 [==============================] - 0s 86ms/step - loss: 3.6192 - val_loss: 2.8380
# Epoch 428/10000
# 1/1 [==============================] - 0s 96ms/step - loss: 3.6180 - val_loss: 2.8368
# Epoch 429/10000
# 1/1 [==============================] - 0s 55ms/step - loss: 3.6168 - val_loss: 2.8356
# Epoch 430/10000
# 1/1 [==============================] - 0s 52ms/step - loss: 3.6155 - val_loss: 2.8344
# Epoch 431/10000
# 1/1 [==============================] - 0s 59ms/step - loss: 3.6143 - val_loss: 2.8332
# Epoch 432/10000
# 1/1 [==============================] - 0s 49ms/step - loss: 3.6131 - val_loss: 2.8320
# Epoch 433/10000
# 1/1 [==============================] - 0s 43ms/step - loss: 3.6118 - val_loss: 2.8309
# Epoch 434/10000
# 1/1 [==============================] - 0s 83ms/step - loss: 3.6106 - val_loss: 2.8297
# Epoch 435/10000
# 1/1 [==============================] - 0s 74ms/step - loss: 3.6094 - val_loss: 2.8285
# Epoch 436/10000
# 1/1 [==============================] - 0s 53ms/step - loss: 3.6081 - val_loss: 2.8273
# Epoch 437/10000
# 1/1 [==============================] - 0s 57ms/step - loss: 3.6069 - val_loss: 2.8261
# Epoch 438/10000
# 1/1 [==============================] - 0s 81ms/step - loss: 3.6058 - val_loss: 2.8250
# Epoch 439/10000
# 1/1 [==============================] - 0s 68ms/step - loss: 3.6048 - val_loss: 2.8238
# Epoch 440/10000
# 1/1 [==============================] - 0s 47ms/step - loss: 3.6037 - val_loss: 2.8227
# Epoch 441/10000
# 1/1 [==============================] - 0s 44ms/step - loss: 3.6027 - val_loss: 2.8216
# Epoch 442/10000
# 1/1 [==============================] - 0s 40ms/step - loss: 3.6016 - val_loss: 2.8204
# Epoch 443/10000
# 1/1 [==============================] - 0s 82ms/step - loss: 3.6006 - val_loss: 2.8193
# Epoch 444/10000
# 1/1 [==============================] - 0s 61ms/step - loss: 3.5996 - val_loss: 2.8182
# Epoch 445/10000
# 1/1 [==============================] - 0s 84ms/step - loss: 3.5985 - val_loss: 2.8172
# Epoch 446/10000
# 1/1 [==============================] - 0s 78ms/step - loss: 3.5975 - val_loss: 2.8161
# Epoch 447/10000
# 1/1 [==============================] - 0s 50ms/step - loss: 3.5965 - val_loss: 2.8150
# Epoch 448/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 3.5955 - val_loss: 2.8139
# Epoch 449/10000
# 1/1 [==============================] - 0s 39ms/step - loss: 3.5945 - val_loss: 2.8129
# Epoch 450/10000
# 1/1 [==============================] - 0s 42ms/step - loss: 3.5934 - val_loss: 2.8118
# Epoch 451/10000
# 1/1 [==============================] - 0s 39ms/step - loss: 3.5924 - val_loss: 2.8107
# Epoch 452/10000
# 1/1 [==============================] - 0s 35ms/step - loss: 3.5914 - val_loss: 2.8097
# Epoch 453/10000
# 1/1 [==============================] - 0s 38ms/step - loss: 3.5904 - val_loss: 2.8086
# Epoch 454/10000
# 1/1 [==============================] - 0s 35ms/step - loss: 3.5894 - val_loss: 2.8075
# Epoch 455/10000
# 1/1 [==============================] - 0s 39ms/step - loss: 3.5884 - val_loss: 2.8065
# Epoch 456/10000
# 1/1 [==============================] - 0s 46ms/step - loss: 3.5873 - val_loss: 2.8054
# Epoch 457/10000
# 1/1 [==============================] - 0s 39ms/step - loss: 3.5863 - val_loss: 2.8044
# Epoch 458/10000
# 1/1 [==============================] - 0s 38ms/step - loss: 3.5853 - val_loss: 2.8033
# Epoch 459/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 3.5843 - val_loss: 2.8022
# Epoch 460/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 3.5833 - val_loss: 2.8012
# Epoch 461/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 3.5822 - val_loss: 2.8001
# Epoch 462/10000
# 1/1 [==============================] - 0s 44ms/step - loss: 3.5812 - val_loss: 2.7990
# Epoch 463/10000
# 1/1 [==============================] - 0s 39ms/step - loss: 3.5802 - val_loss: 2.7980
# Epoch 464/10000
# 1/1 [==============================] - 0s 31ms/step - loss: 3.5792 - val_loss: 2.7969
# Epoch 465/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 3.5781 - val_loss: 2.7959
# Epoch 466/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 3.5771 - val_loss: 2.7948
# Epoch 467/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 3.5761 - val_loss: 2.7937
# Epoch 468/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 3.5750 - val_loss: 2.7926
# Epoch 469/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 3.5740 - val_loss: 2.7916
# Epoch 470/10000
# 1/1 [==============================] - 0s 35ms/step - loss: 3.5730 - val_loss: 2.7905
# Epoch 471/10000
# 1/1 [==============================] - 0s 42ms/step - loss: 3.5720 - val_loss: 2.7894
# ...
# Epoch 1728/10000
# 1/1 [==============================] - 0s 35ms/step - loss: 2.5910 - val_loss: 2.0770
# Epoch 1729/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 2.5905 - val_loss: 2.0768
# Epoch 1730/10000
# 1/1 [==============================] - 0s 35ms/step - loss: 2.5900 - val_loss: 2.0766
# Epoch 1731/10000
# 1/1 [==============================] - 0s 50ms/step - loss: 2.5896 - val_loss: 2.0765
# Epoch 1732/10000
# 1/1 [==============================] - 0s 49ms/step - loss: 2.5891 - val_loss: 2.0763
# Epoch 1733/10000
# 1/1 [==============================] - 0s 64ms/step - loss: 2.5886 - val_loss: 2.0761
# Epoch 1734/10000
# 1/1 [==============================] - 0s 45ms/step - loss: 2.5881 - val_loss: 2.0759
# Epoch 1735/10000
# 1/1 [==============================] - 0s 44ms/step - loss: 2.5876 - val_loss: 2.0758
# Epoch 1736/10000
# 1/1 [==============================] - 0s 50ms/step - loss: 2.5871 - val_loss: 2.0756
# Epoch 1737/10000
# 1/1 [==============================] - 0s 35ms/step - loss: 2.5866 - val_loss: 2.0754
# Epoch 1738/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 2.5861 - val_loss: 2.0753
# Epoch 1739/10000
# 1/1 [==============================] - 0s 54ms/step - loss: 2.5856 - val_loss: 2.0751
# Epoch 1740/10000
# 1/1 [==============================] - 0s 45ms/step - loss: 2.5851 - val_loss: 2.0749
# Epoch 1741/10000
# 1/1 [==============================] - 0s 42ms/step - loss: 2.5847 - val_loss: 2.0748
# Epoch 1742/10000
# 1/1 [==============================] - 0s 42ms/step - loss: 2.5843 - val_loss: 2.0747
# Epoch 1743/10000
# 1/1 [==============================] - 0s 45ms/step - loss: 2.5839 - val_loss: 2.0746
# Epoch 1744/10000
# 1/1 [==============================] - 0s 49ms/step - loss: 2.5835 - val_loss: 2.0745
# Epoch 1745/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 2.5831 - val_loss: 2.0744
# Epoch 1746/10000
# 1/1 [==============================] - 0s 34ms/step - loss: 2.5826 - val_loss: 2.0743
# Epoch 1747/10000
# 1/1 [==============================] - 0s 39ms/step - loss: 2.5822 - val_loss: 2.0742
# Epoch 1748/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 2.5818 - val_loss: 2.0742
# Epoch 1749/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 2.5814 - val_loss: 2.0741
# Epoch 1750/10000
# 1/1 [==============================] - 0s 42ms/step - loss: 2.5809 - val_loss: 2.0741
# Epoch 1751/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 2.5805 - val_loss: 2.0740
# Epoch 1752/10000
# 1/1 [==============================] - 0s 45ms/step - loss: 2.5801 - val_loss: 2.0740
# Epoch 1753/10000
# 1/1 [==============================] - 0s 44ms/step - loss: 2.5797 - val_loss: 2.0740
# Epoch 1754/10000
# 1/1 [==============================] - 0s 46ms/step - loss: 2.5793 - val_loss: 2.0739
# Epoch 1755/10000
# 1/1 [==============================] - 0s 52ms/step - loss: 2.5789 - val_loss: 2.0738
# Epoch 1756/10000
# 1/1 [==============================] - 0s 38ms/step - loss: 2.5786 - val_loss: 2.0737
# Epoch 1757/10000
# 1/1 [==============================] - 0s 58ms/step - loss: 2.5782 - val_loss: 2.0736
# Epoch 1758/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 2.5778 - val_loss: 2.0734
# Epoch 1759/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 2.5775 - val_loss: 2.0733
# Epoch 1760/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 2.5771 - val_loss: 2.0731
# Epoch 1761/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 2.5767 - val_loss: 2.0729
# Epoch 1762/10000
# 1/1 [==============================] - 0s 34ms/step - loss: 2.5764 - val_loss: 2.0727
# Epoch 1763/10000
# 1/1 [==============================] - 0s 32ms/step - loss: 2.5761 - val_loss: 2.0724
# Epoch 1764/10000
# 1/1 [==============================] - 0s 47ms/step - loss: 2.5757 - val_loss: 2.0721
# Epoch 1765/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 2.5753 - val_loss: 2.0718
# Epoch 1766/10000
# 1/1 [==============================] - 0s 49ms/step - loss: 2.5750 - val_loss: 2.0715
# Epoch 1767/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 2.5747 - val_loss: 2.0712
# Epoch 1768/10000
# 1/1 [==============================] - 0s 42ms/step - loss: 2.5745 - val_loss: 2.0708
# Epoch 1769/10000
# 1/1 [==============================] - 0s 49ms/step - loss: 2.5742 - val_loss: 2.0705
# Epoch 1770/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 2.5739 - val_loss: 2.0703
# Epoch 1771/10000
# 1/1 [==============================] - 0s 45ms/step - loss: 2.5736 - val_loss: 2.0702
# Epoch 1772/10000
# 1/1 [==============================] - 0s 47ms/step - loss: 2.5732 - val_loss: 2.0701
# Epoch 1773/10000
# 1/1 [==============================] - 0s 42ms/step - loss: 2.5729 - val_loss: 2.0701
# Epoch 1774/10000
# 1/1 [==============================] - 0s 55ms/step - loss: 2.5726 - val_loss: 2.0701
# Epoch 1775/10000
# 1/1 [==============================] - 0s 46ms/step - loss: 2.5723 - val_loss: 2.0700
# Epoch 1776/10000
# 1/1 [==============================] - 0s 51ms/step - loss: 2.5721 - val_loss: 2.0700
# Epoch 1777/10000
# 1/1 [==============================] - 0s 42ms/step - loss: 2.5718 - val_loss: 2.0700
# Epoch 1778/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 2.5716 - val_loss: 2.0699
# Epoch 1779/10000
# 1/1 [==============================] - 0s 38ms/step - loss: 2.5714 - val_loss: 2.0699
# Epoch 1780/10000
# 1/1 [==============================] - 0s 34ms/step - loss: 2.5711 - val_loss: 2.0698
# Epoch 1781/10000
# 1/1 [==============================] - 0s 42ms/step - loss: 2.5709 - val_loss: 2.0698
# Epoch 1782/10000
# 1/1 [==============================] - 0s 40ms/step - loss: 2.5706 - val_loss: 2.0697
# Epoch 1783/10000
# 1/1 [==============================] - 0s 43ms/step - loss: 2.5704 - val_loss: 2.0697
# Epoch 1784/10000
# 1/1 [==============================] - 0s 42ms/step - loss: 2.5702 - val_loss: 2.0696
# Epoch 1785/10000
# 1/1 [==============================] - 0s 34ms/step - loss: 2.5699 - val_loss: 2.0696
# Epoch 1786/10000
# 1/1 [==============================] - 0s 52ms/step - loss: 2.5697 - val_loss: 2.0695
# Epoch 1787/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 2.5694 - val_loss: 2.0695
# Epoch 1788/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 2.5692 - val_loss: 2.0694
# Epoch 1789/10000
# 1/1 [==============================] - 0s 38ms/step - loss: 2.5690 - val_loss: 2.0694
# Epoch 1790/10000
# 1/1 [==============================] - 0s 42ms/step - loss: 2.5687 - val_loss: 2.0693
# Epoch 1791/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 2.5685 - val_loss: 2.0693
# Epoch 1792/10000
# 1/1 [==============================] - 0s 38ms/step - loss: 2.5682 - val_loss: 2.0692
# Epoch 1793/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 2.5680 - val_loss: 2.0691
# Epoch 1794/10000
# 1/1 [==============================] - 0s 33ms/step - loss: 2.5678 - val_loss: 2.0691
# Epoch 1795/10000
# 1/1 [==============================] - 0s 33ms/step - loss: 2.5675 - val_loss: 2.0690
# Epoch 1796/10000
# 1/1 [==============================] - 0s 40ms/step - loss: 2.5673 - val_loss: 2.0690
# Epoch 1797/10000
# 1/1 [==============================] - 0s 33ms/step - loss: 2.5670 - val_loss: 2.0689
# Epoch 1798/10000
# 1/1 [==============================] - 0s 34ms/step - loss: 2.5668 - val_loss: 2.0689
# Epoch 1799/10000
# 1/1 [==============================] - 0s 33ms/step - loss: 2.5665 - val_loss: 2.0688
# Epoch 1800/10000
# 1/1 [==============================] - 0s 51ms/step - loss: 2.5663 - val_loss: 2.0687
# Epoch 1801/10000
# 1/1 [==============================] - 0s 46ms/step - loss: 2.5661 - val_loss: 2.0687
# Epoch 1802/10000
# 1/1 [==============================] - 0s 35ms/step - loss: 2.5658 - val_loss: 2.0686
# Epoch 1803/10000
# 1/1 [==============================] - 0s 33ms/step - loss: 2.5656 - val_loss: 2.0686
# Epoch 1804/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 2.5654 - val_loss: 2.0685
# Epoch 1805/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 2.5651 - val_loss: 2.0685
# Epoch 1806/10000
# 1/1 [==============================] - 0s 46ms/step - loss: 2.5649 - val_loss: 2.0684
# Epoch 1807/10000
# 1/1 [==============================] - 0s 39ms/step - loss: 2.5646 - val_loss: 2.0683
# Epoch 1808/10000
# 1/1 [==============================] - 0s 38ms/step - loss: 2.5644 - val_loss: 2.0683
# Epoch 1809/10000
# 1/1 [==============================] - 0s 38ms/step - loss: 2.5642 - val_loss: 2.0682
# Epoch 1810/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 2.5639 - val_loss: 2.0682
# Epoch 1811/10000
# 1/1 [==============================] - 0s 45ms/step - loss: 2.5637 - val_loss: 2.0681
# Epoch 1812/10000
# 1/1 [==============================] - 0s 35ms/step - loss: 2.5634 - val_loss: 2.0681
# Epoch 1813/10000
# 1/1 [==============================] - 0s 39ms/step - loss: 2.5632 - val_loss: 2.0680
# Epoch 1814/10000
# 1/1 [==============================] - 0s 38ms/step - loss: 2.5630 - val_loss: 2.0679
# Epoch 1815/10000
# 1/1 [==============================] - 0s 33ms/step - loss: 2.5627 - val_loss: 2.0679
# Epoch 1816/10000
# 1/1 [==============================] - 0s 34ms/step - loss: 2.5625 - val_loss: 2.0678
# Epoch 1817/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 2.5622 - val_loss: 2.0678
# Epoch 1818/10000
# 1/1 [==============================] - 0s 34ms/step - loss: 2.5620 - val_loss: 2.0677
# Epoch 1819/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 2.5617 - val_loss: 2.0676
# Epoch 1820/10000
# 1/1 [==============================] - 0s 48ms/step - loss: 2.5615 - val_loss: 2.0676
# Epoch 1821/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 2.5612 - val_loss: 2.0675
# Epoch 1822/10000
# 1/1 [==============================] - 0s 43ms/step - loss: 2.5609 - val_loss: 2.0675
# Epoch 1823/10000
# 1/1 [==============================] - 0s 38ms/step - loss: 2.5606 - val_loss: 2.0674
# Epoch 1824/10000
# 1/1 [==============================] - 0s 44ms/step - loss: 2.5604 - val_loss: 2.0674
# Epoch 1825/10000
# 1/1 [==============================] - 0s 50ms/step - loss: 2.5601 - val_loss: 2.0673
# Epoch 1826/10000
# 1/1 [==============================] - 0s 49ms/step - loss: 2.5598 - val_loss: 2.0672
# Epoch 1827/10000
# 1/1 [==============================] - 0s 40ms/step - loss: 2.5595 - val_loss: 2.0672
# Epoch 1828/10000
# 1/1 [==============================] - 0s 38ms/step - loss: 2.5591 - val_loss: 2.0671
# Epoch 1829/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 2.5588 - val_loss: 2.0671
# Epoch 1830/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 2.5585 - val_loss: 2.0670
# Epoch 1831/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 2.5582 - val_loss: 2.0670
# Epoch 1832/10000
# 1/1 [==============================] - 0s 46ms/step - loss: 2.5579 - val_loss: 2.0669
# Epoch 1833/10000
# 1/1 [==============================] - 0s 45ms/step - loss: 2.5576 - val_loss: 2.0669
# Epoch 1834/10000
# 1/1 [==============================] - 0s 47ms/step - loss: 2.5573 - val_loss: 2.0668
# Epoch 1835/10000
# 1/1 [==============================] - 0s 44ms/step - loss: 2.5569 - val_loss: 2.0668
# Epoch 1836/10000
# 1/1 [==============================] - 0s 40ms/step - loss: 2.5566 - val_loss: 2.0667
# Epoch 1837/10000
# 1/1 [==============================] - 0s 43ms/step - loss: 2.5563 - val_loss: 2.0667
# Epoch 1838/10000
# 1/1 [==============================] - 0s 40ms/step - loss: 2.5560 - val_loss: 2.0666
# Epoch 1839/10000
# 1/1 [==============================] - 0s 48ms/step - loss: 2.5556 - val_loss: 2.0666
# Epoch 1840/10000
# 1/1 [==============================] - 0s 44ms/step - loss: 2.5553 - val_loss: 2.0665
# Epoch 1841/10000
# 1/1 [==============================] - 0s 43ms/step - loss: 2.5550 - val_loss: 2.0665
# Epoch 1842/10000
# 1/1 [==============================] - 0s 43ms/step - loss: 2.5546 - val_loss: 2.0664
# Epoch 1843/10000
# 1/1 [==============================] - 0s 40ms/step - loss: 2.5543 - val_loss: 2.0664
# Epoch 1844/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 2.5540 - val_loss: 2.0664
# Epoch 1845/10000
# 1/1 [==============================] - 0s 44ms/step - loss: 2.5536 - val_loss: 2.0663
# Epoch 1846/10000
# 1/1 [==============================] - 0s 40ms/step - loss: 2.5533 - val_loss: 2.0663
# Epoch 1847/10000
# 1/1 [==============================] - 0s 42ms/step - loss: 2.5530 - val_loss: 2.0662
# Epoch 1848/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 2.5526 - val_loss: 2.0662
# Epoch 1849/10000
# 1/1 [==============================] - 0s 44ms/step - loss: 2.5523 - val_loss: 2.0661
# Epoch 1850/10000
# 1/1 [==============================] - 0s 38ms/step - loss: 2.5519 - val_loss: 2.0661
# Epoch 1851/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 2.5516 - val_loss: 2.0660
# Epoch 1852/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 2.5513 - val_loss: 2.0660
# Epoch 1853/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 2.5509 - val_loss: 2.0659
# Epoch 1854/10000
# 1/1 [==============================] - 0s 35ms/step - loss: 2.5506 - val_loss: 2.0659
# Epoch 1855/10000
# 1/1 [==============================] - 0s 35ms/step - loss: 2.5502 - val_loss: 2.0658
# Epoch 1856/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 2.5499 - val_loss: 2.0658
# Epoch 1857/10000
# 1/1 [==============================] - 0s 34ms/step - loss: 2.5496 - val_loss: 2.0657
# Epoch 1858/10000
# 1/1 [==============================] - 0s 47ms/step - loss: 2.5492 - val_loss: 2.0657
# Epoch 1859/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 2.5489 - val_loss: 2.0656
# Epoch 1860/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 2.5485 - val_loss: 2.0656
# Epoch 1861/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 2.5482 - val_loss: 2.0655
# Epoch 1862/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 2.5478 - val_loss: 2.0655
# Epoch 1863/10000
# 1/1 [==============================] - 0s 33ms/step - loss: 2.5475 - val_loss: 2.0654
# Epoch 1864/10000
# 1/1 [==============================] - 0s 48ms/step - loss: 2.5471 - val_loss: 2.0654
# Epoch 1865/10000
# 1/1 [==============================] - 0s 43ms/step - loss: 2.5468 - val_loss: 2.0653
# Epoch 1866/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 2.5464 - val_loss: 2.0653
# Epoch 1867/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 2.5461 - val_loss: 2.0652
# Epoch 1868/10000
# 1/1 [==============================] - 0s 34ms/step - loss: 2.5457 - val_loss: 2.0652
# Epoch 1869/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 2.5454 - val_loss: 2.0651
# Epoch 1870/10000
# 1/1 [==============================] - 0s 36ms/step - loss: 2.5450 - val_loss: 2.0651
# Epoch 1871/10000
# 1/1 [==============================] - 0s 45ms/step - loss: 2.5447 - val_loss: 2.0650
# Epoch 1872/10000
# 1/1 [==============================] - 0s 46ms/step - loss: 2.5443 - val_loss: 2.0650
# Epoch 1873/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 2.5440 - val_loss: 2.0651
# Epoch 1874/10000
# 1/1 [==============================] - 0s 35ms/step - loss: 2.5436 - val_loss: 2.0652
# Epoch 1875/10000
# 1/1 [==============================] - 0s 37ms/step - loss: 2.5433 - val_loss: 2.0653
# Epoch 1876/10000
# 1/1 [==============================] - 0s 51ms/step - loss: 2.5429 - val_loss: 2.0654
# Epoch 1877/10000
# 1/1 [==============================] - 0s 35ms/step - loss: 2.5426 - val_loss: 2.0655
# Epoch 1878/10000
# 1/1 [==============================] - 0s 50ms/step - loss: 2.5422 - val_loss: 2.0656
# Epoch 1879/10000
# 1/1 [==============================] - 0s 42ms/step - loss: 2.5419 - val_loss: 2.0658
# Epoch 1880/10000
# 1/1 [==============================] - 0s 48ms/step - loss: 2.5415 - val_loss: 2.0659
# Epoch 1881/10000
# 1/1 [==============================] - 0s 41ms/step - loss: 2.5412 - val_loss: 2.0660
# Epoch 1882/10000
# 1/1 [==============================] - 0s 40ms/step - loss: 2.5408 - val_loss: 2.0661
# Epoch 1882: early stopping

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()

# %% [markdown]
# ### Prediction Years

# %%
predictions2005 = model.predict(test2005)
predictions2020 = model.predict(test2020)
predictions1999 = model.predict(test1999)

# %%
predictions2005
# Out:
# array([[16.667664]], dtype=float32)

# %%
predictions2020
# Out:
# array([[15.261906]], dtype=float32)

# %%
predictions1999
# Out:
# array([[13.122264]], dtype=float32)
